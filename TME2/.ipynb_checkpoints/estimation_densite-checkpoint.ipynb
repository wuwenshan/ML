# %% [markdown]
# # <center><font color='red'> TME 2 - Estimation de densité </font></center>

# %% [markdown]
# ## <center><code style="background:yellow; color:black"> Données : API Google Places, Points d’intérêt de Paris </code></center>

# %% [markdown]
# Télécharger l’archive sur le site de l’ue. Elle contient un dictionnaire avec des informations sur différents types de points d’intérêt (POI) de Paris. Chaque clé du dictionnaire correspond à un type de POI (restaurant, distributeur d’argent, . . . ) et la valeur associée est un dictionnaire avec l’identifiant google map comme clé, et les informations sur le POI : les coordonnées GPS, sa notation, son nom, ses types, le niveau des prix. <br>Le code fourni permet de visualiser les données et charger la matrice des coordonnées GPS.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pickle


plt.ion()
parismap = mpimg.imread('data/paris-48.806-2.23--48.916-2.48.jpg')

## coordonnees GPS de la carte
xmin,xmax = 2.23,2.48   ## coord_x min et max
ymin,ymax = 48.806,48.916 ## coord_y min et max

def show_map():
    plt.imshow(parismap,extent=[xmin,xmax,ymin,ymax],aspect=1.5)
    ## extent pour controler l'echelle du plan

poidata = pickle.load(open("data/poi-paris.pkl","rb"))
## liste des types de point of interest (poi)
print("Liste des types de POI" , ", ".join(poidata.keys()))

## Choix d'un poi
typepoi = "night_club"

## Creation de la matrice des coordonnees des POI
geo_mat = np.zeros((len(poidata[typepoi]),2))
for i,(k,v) in enumerate(poidata[typepoi].items()):
    geo_mat[i,:]=v[0]   
    
print(geo_mat)    

## Affichage brut des poi
show_map()
## alpha permet de regler la transparence, s la taille
plt.scatter(geo_mat[:,1],geo_mat[:,0],alpha=0.8,s=3)

###################################################

# discretisation pour l'affichage des modeles d'estimation de densite
steps = 100
xx,yy = np.meshgrid(np.linspace(xmin,xmax,steps),np.linspace(ymin,ymax,steps))
grid = np.c_[xx.ravel(),yy.ravel()]

# A remplacer par res = monModele.predict(grid).reshape(steps,steps)
res = np.random.random((steps,steps))
plt.figure()
show_map()
plt.imshow(res,extent=[xmin,xmax,ymin,ymax],interpolation='none',\
               alpha=0.3,origin = "lower")
plt.colorbar()
plt.scatter(geo_mat[:,0],geo_mat[:,1],alpha=0.3)
# Out:
# Liste des types de POI furniture_store, laundry, bakery, cafe, home_goods_store, clothing_store, atm, lodging, night_club, convenience_store, restaurant, bar
# [[48.8753446  2.3167161]
#  [48.8621282  2.3422869]
#  [48.8798307  2.3541009]
#  ...
#  [48.8839193  2.3266756]
#  [48.8854041  2.2572311]
#  [48.8922301  2.3502542]]

# %%
import googlemaps as gmaps

APIKEY = 'AIzaSyBipQNDtCK-BMk53RuBRD0bfubbzTLP87w'

gm = gmaps.Client(APIKEY)

COORD = [(48.806,2.23),(48.916,2.48)]


DX = COORD[1][0]-COORD[0][0]
DY = COORD[1][1]-COORD[0][1]
TYPES = ["clothing_store", "bar","laundry","bakery", "lodging", "restaurant","cafe", "atm", "night_club","convenience_store","furniture_store","home_goods_store"]
cpt = 0

def get_list(typreq,totstep):
    res = dict()
    global cpt
    for i in range(totstep):
        for j in range(totstep):
            cpt+=1
            coord = (COORD[0][0]+i*DX*1./totstep,COORD[0][1]+j*DY*1./totstep)
            print(typreq,i,j,len(res),cpt)
            res.update([ (x['place_id'],(x['geometry']['location']['lat'],x['geometry']['location']['lng'])) for x in gm.places_radar(coord, 2000, type=typreq)['results']])
    return res

def treat_dic(d):
    global cpt
    for i,(k,v) in enumerate(d.items()):
        print(i,len(d),cpt)
        res=gm.place(k)['result']
        cpt+=1
        d[k]=(v,res.get('rating',-1),res.get('name',""),res.get('types',[]),res.get('price_level',-1))
    return d
res = dict()
for typreq in TYPES:
    res[typreq] = get_list(typreq,20)
    pickle.dump(res[typreq],open("res"+typreq+".pkl","wb"))

for typreq in TYPES:
    res[typreq]=treat_dic(res[typreq])
    pickle.dump(res[typreq],open("rescomplet"+typreq+".pkl","wb"))
pickle.dump(res,open("restotal.pkl","wb"))
# Out:
# clothing_store 0 0 0 1
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-c88384e0b514> in <module>()
#      34 res = dict()
#      35 for typreq in TYPES:
# ---> 36     res[typreq] = get_list(typreq,20)
#      37     pickle.dump(res[typreq],open("res"+typreq+".pkl","wb"))
#      38
#
# <ipython-input-3-c88384e0b514> in get_list(typreq, totstep)
#      21             coord = (COORD[0][0]+i*DX*1./totstep,COORD[0][1]+j*DY*1./totstep)
#      22             print(typreq,i,j,len(res),cpt)
# ---> 23             res.update([ (x['place_id'],(x['geometry']['location']['lat'],x['geometry']['location']['lng'])) for x in gm.places_radar(coord, 2000, type=typreq)['results']])
#      24     return res
#      25
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# ~\Anaconda3\lib\site-packages\googlemaps\places.py in places_radar(client, location, radius, keyword, min_price, max_price, name, open_now, type)
#     198     return _places(client, "radar", location=location, radius=radius,
#     199                    keyword=keyword, min_price=min_price, max_price=max_price,
# --> 200                    name=name, open_now=open_now, type=type)
#     201
#     202
#
# ~\Anaconda3\lib\site-packages\googlemaps\places.py in _places(client, url_part, query, location, radius, keyword, language, min_price, max_price, name, open_now, rank_by, type, page_token)
#     233
#     234     url = "/maps/api/place/%ssearch/json" % url_part
# --> 235     return client._request(url, params)
#     236
#     237
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     251                 result = extract_body(response)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#     255             return result
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     265     def _get_body(self, response):
#     266         if response.status_code != 200:
# --> 267             raise googlemaps.exceptions.HTTPError(response.status_code)
#     268
#     269         body = response.json()
#
# HTTPError: HTTP Error: 404

# %% [markdown]
# ## <center><code style="background:yellow; color:black"> Expérimentations </code></center>

# %% [markdown]
# L’objectif de ce TME est de prendre en main les algorithmes d’estimation de densité. Choisissez un type de POI à traiter, l’objectif est d’estimer la loi de densité $p(x, y)$ géographique des POIs sur Paris(*x*, *y* sont les coordonnées GPS d’un lieu). Vous étudierez les deux algorithmes suivants :
# <ul>
#     <li> Méthode des histogrammes. </li>
#     <li> Méthode à noyaux (Parzen pour commencer puis le noyaux de votre choix - gaussien par exemple). </li>
# </ul>
# Pour chacune des expériences, vous visualiserez les résultats obtenus en faisant une discrétisation de l’espace et en évaluant en chaque case la densité donnée par vos modèles (la méthode par histogramme vous donne directement la discrétisation à employer). Le code pour l’affichage vous est fourni. Expérimentez selon différents réglages. Réfléchissez en particulier aux questions suivantes :
# <ul>
#     <li> Que se passe-t-il pour une faible/forte discrétisation pour la méthode des histogrammes ? </li>
#     <li> Quel est le rôle des paramètres des méthodes à noyaux ? </li>
#     <li> Comment choisir de manière automatique les meilleurs paramètres ? </li>
#     <li> La question reliée : comment estimer la qualité de votre modèle ? </li>
# </ul>
# Vous pouvez par la suite essayer de comparer la densité des différents type de POI. Vous pouvez également vous intéresser à un problème de classification qui consiste à prédire la note d’un POI en fonction de son emplacement. Dans ce dernier contexte de classification supervisée, vous pouvez mettre en œuvre l’estimateur de Nadaraya-Watson et les k-plus proches voisins.

# %%
def getHistEstim(xmin, xmax, ymin, ymax, pas, geomat):
    x_inter = np.arange(xmin, xmax, pas)
    y_inter = np.arange(ymin, ymax, pas)
    mat_xy = np.zeros((len(x_inter),len(y_inter)))
    
    for i in range(geomat.shape[0]):
        y = geomat[i][0]
        x = geomat[i][1]
        mat_xy[ np.where(x>x_inter)[0][-1], np.where(y>y_inter)[0][-1] ] += 1
    
    N = geomat.shape[0]
    dens = np.zeros( np.where((mat_xy!=0),1,0).sum() )
    comptage = np.argwhere((mat_xy!=0)) # indices où c'est différent de 0
    
    for i in range(len(comptage)):
        dens[i] = mat_xy[comptage[i][0], comptage[i][1]] / ( N * pas )
        
    plt.plot(dens)
    plt.xlabel("points (par indice)")
    plt.ylabel("densité")
    plt.title("histogramme")
    plt.show()
        
    plt.imshow(mat_xy, cmap="hot")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("histogramme 2D")
    plt.colorbar()
    
    return None
    
    
getHistEstim(xmin, xmax, ymin, ymax, 0.02, geo_mat)

# %%
def parzenWindowEstim(geomat, h, d):
    nbPts = geomat.shape[0]
    dens = np.zeros(nbPts)
    
    for i in range(nbPts):
        y = geomat[i][0]
        x = geomat[i][1]
        dens[i] = np.where( ( ( np.abs( ( x - geomat[:,1] ) / h ) <= 1/2 ) & ( np.abs( ( y - geomat[:,0] ) / h ) <= 1/2 ) ), 1, 0).sum() - 1
    
    densEstim = np.where((dens!=0), (dens/nbPts) / np.power(h,d), 0 )

    densEstim /= np.sum(densEstim)
    
    print(densEstim.shape)
    
    plt.plot(densEstim)
    plt.xlabel("point (par indice)")
    plt.ylabel("densité")
    plt.title("histogramme")
    plt.show()
 
    return None

parzenWindowEstim(geo_mat, 0.01, 2)
# Out:
# (556,)

# %%
def gaussianKernel(x, xi, h, d):
    a = 1 / ( ( np.power( np.sqrt(2*np.pi), d ) * np.power( h, d ) ) )
    b = -( 1 / 2 ) * np.power( (x-xi) / h, 2 )
    return a*np.exp(b)

def parzenWindowGaussEstim(geomat, h, d):
    N = geomat.shape[0]
    dens_x = np.zeros(N)
    dens_y = np.zeros(N)
    
    for i in range(N):
        y = geomat[i][0]
        x = geomat[i][0]
        for j in range(N):
            if j != i:
                y_2 = geomat[j][0]
                x_2 = geomat[j][0]
                dens_x[i] += gaussianKernel(x, x_2, h, d)
                dens_y[i] += gaussianKernel(y, y_2, h, d)
    
    densEstim_x = np.where((dens_x!=0), (1/N)*(1/np.power(h,d))*dens_x, 0 )
    densEstim_y = np.where((dens_y!=0), (1/N)*(1/np.power(h,d))*dens_y, 0 )
    
    densEstim = densEstim_x + densEstim_y
    densEstim /= np.sum(densEstim)
    
    plt.bar(np.arange(len(densEstim)), densEstim)
    
#     plt.plot(densEstim)
#     plt.xlabel("point (par indice)")
#     plt.ylabel("densité")
#     plt.title("densité x")
#     plt.show()
    
#     plt.plot(densEstim_y)
#     plt.xlabel("point (par indice)")
#     plt.ylabel("densité")
#     plt.title("densité y")
#     plt.show()
    
    return None
    
parzenWindowGaussEstim(geo_mat, 0.01, 2)

# %%
poidata
# Out:
# {'furniture_store': {'ChIJvQW3LzBu5kcR1K1RinPHWuo': ((48.86663159999999,
#     2.3316366),
#    2.2,
#    'Unopiu',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJPa034vBu5kcRgPhYMUxo0Dk': ((48.90328890000001, 2.339881399999999),
#    -1,
#    'Olivier Hutzemakers',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJS2paJgVy5kcRsWnyhE-Ng4Y': ((48.84763299999999, 2.3753779),
#    -1,
#    'Téodor',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ5_Q5YZRv5kcRs3k9SIdrmtM': ((48.8798415, 2.2971538),
#    5,
#    'Féau and Co.',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJvw0d809w5kcRvg7fJrlayzE': ((48.8279332, 2.3090737),
#    -1,
#    'Patoux Florence Marie-therese',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ86G-5alt5kcRtPN69Wx3nsA': ((48.8890514, 2.4137347),
#    1,
#    'Au Salon Du Meuble',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJI8hEZT1w5kcRwuzXQpYW5mg': ((48.8450829, 2.3001058),
#    3.6,
#    'Bricorama',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJG2Jx6YBx5kcRt01WAbgdvys': ((48.8189954, 2.3616023),
#    -1,
#    'Fachan Robert',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJq6q2OZ5l5kcRBJAOq9Z2m-k': ((48.8992709, 2.2618424),
#    3.8,
#    'Cuisines Références',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ1T7hEUJu5kcRY-n7-sBacX4': ((48.8821368, 2.3458452),
#    4.8,
#    'Krea 99',
#    ['jewelry_store',
#     'clothing_store',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJZwozmhJv5kcR61nTA-AHEAY': ((48.908004, 2.3051652),
#    5,
#    'Pashev Entreprise',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJmYBrpJ1y5kcRQ7DfxvAWahI': ((48.85284710000001, 2.4262186),
#    -1,
#    'Oudia Noureddine',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJo-lF1uxt5kcRONVgWod9KDw': ((48.867983, 2.389954),
#    3.7,
#    'BedUp® Paris 20',
#    ['general_contractor',
#     'lodging',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJqXZdTnNy5kcRF45WLS14qxI': ((48.84958499999999, 2.3893007),
#    -1,
#    'A.M.S Agencement Menuiserie Services',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJwbOsxBdw5kcRr7RQbH1oGbA': ((48.84558399999999, 2.2979308),
#    2.3,
#    'Cuisines CORMIER - Cuisines & Agencements haut de gamme',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJcbDaUgpv5kcRZoXp6oW4IBc': ((48.899718, 2.306318),
#    3.6,
#    'Bricorama',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJQ6gKTqJy5kcRpfTC7LTcJDI': ((48.84754979999999, 2.4362183),
#    -1,
#    'Atelier du 15',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJa7EkMAly5kcR0EfZGyKx3X4': ((48.8509994, 2.3814537),
#    4.9,
#    'Les Chi(n)euses',
#    ['store',
#     'furniture_store',
#     'home_goods_store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJFXEB7E1y5kcRusfa4-Y-nV4': ((48.8190679, 2.396562799999999),
#    -1,
#    '26 Dream Meubles',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJEVLT0AFy5kcRE7-nvEBZJb4': ((48.8527552, 2.3670081),
#    3.6,
#    'Scandilodge',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJx6_Hkwlt5kcRRs2hXfP-z5U': ((48.880785, 2.4156019),
#    -1,
#    'Eberlin Pierre (Ets)',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJBad8B1Vl5kcRGmitUT92u6I': ((48.8600506, 2.2750157),
#    -1,
#    'DAUMAL',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ8-PAy2du5kcRKH26ELc-aHg': ((48.88811309999999, 2.349367299999999),
#    5,
#    'Romano Décoration',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJE8Xm279v5kcRuVlQg6l5EcA': ((48.878936, 2.301325),
#    5,
#    'Victoria Créations',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJISIuqAVu5kcR42E9Puf6YHs': ((48.8709753, 2.3353917),
#    4.8,
#    'UBER-MODERN',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJn9Y-RsQS5kcR_NDYWXkwRmU': ((48.8820854, 2.4698289),
#    3,
#    'Flexa',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJqwPa-cBv5kcR4rATgBR3zjU': ((48.87527069999999, 2.304111799999999),
#    5,
#    'Somon Franck',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ_4K01VRl5kcRZNAgo0oa33w': ((48.8579326, 2.2742123),
#    3.8,
#    'La Chaise Longue',
#    ['home_goods_store',
#     'department_store',
#     'furniture_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJaXidpSly5kcRcIqhJjxD_PA': ((48.8226948, 2.3664403),
#    4.2,
#    'Art Saigon',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJOYdu4Od65kcRthZ0B4Qx6FU': ((48.8661974, 2.2816399),
#    5,
#    'Open en Ville',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJIXl-lXhv5kcR3fa1QNJ9AvE': ((48.8987191, 2.2875468),
#    -1,
#    'Dimex',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJJ8sKLyBu5kcRZgp_hXvDSQ4': ((48.8582592, 2.3440777),
#    -1,
#    'Manila Management et Finances',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJoyaONXNt5kcRaRASsOoXrBE': ((48.8745531, 2.4205067),
#    5,
#    'LA MARBRERIE CONTEMPORAINE',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJjUtEmBZy5kcRX6BklYe5Gag': ((48.838959, 2.381748),
#    -1,
#    'Bertothi',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJlWzQWhdw5kcRq_5lpMHffDs': ((48.84658030000001, 2.2939568),
#    -1,
#    'Bouillon Dominique',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJLf6x2Ndx5kcRO5USy-44coY': ((48.8566039, 2.3310984),
#    -1,
#    'Galerie Marc PHILIPPE',
#    ['art_gallery',
#     'museum',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ8Uo6Tepv5kcRzqXQEXBCBos': ((48.87385399999999, 2.29824),
#    3.6,
#    'Veneta Cucine Paris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJjdhWEBdw5kcRWdTnkdKGSQo': ((48.84526899999999, 2.294894),
#    -1,
#    'FABRY Sarl',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJm2sGGhdu5kcRrj70syaz76M': ((48.8681022, 2.3492682),
#    5,
#    'Rouxel SAS',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJHfZSv9Jz5kcRW868QG8YFYA': ((48.8143793, 2.3733026),
#    -1,
#    'Espace Cuisines Truffy',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJS-W477Jl5kcRWBtBlnSisss': ((48.9104743, 2.2394028),
#    -1,
#    'Maugendre Renan',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ-eaANY1t5kcRYR7lELOhK4U': ((48.8643207, 2.3905845),
#    3.7,
#    'Déco Stores',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJl4oRRAhl5kcRdOuWb7Z_a1A': ((48.8968296, 2.2484363),
#    3.1,
#    'Mobalpa Courbevoie',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJE342EA1t5kcRyDvFosAPiyU': ((48.8766779, 2.4228877),
#    1,
#    'Matchef',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJobDQhKRx5kcRUFCOTPO0caY': ((48.867537, 2.377186),
#    5,
#    'STEEL LOFT by TITIETSEB MOBILIER INDUSTRIEL',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ9_STJfxt5kcRHIaGSFk8axo': ((48.8611292, 2.3709343),
#    -1,
#    'ouma productions',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJPyZQ6ilu5kcRxf77fPjbkz4': ((48.8575721, 2.3289435),
#    5,
#    'Galerie Bazin',
#    ['art_gallery',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJceDAIGoN5kcRhZywfkjQ4DA': ((48.8384584, 2.4793303),
#    -1,
#    'CFB Concept Aménag Décoration Rénov',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJFQSVnNJx5kcRuPzuSdrji_Y': ((48.84670029999999, 2.3234409),
#    -1,
#    'Serendipity',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJobQxxllu5kcRtqywjGd91PQ': ((48.8933271, 2.3374723),
#    -1,
#    'Chaouat Charles',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJp8YK1Idx5kcR58rNzTppBxA': ((48.82541459999999, 2.3617571),
#    4,
#    "Aux Merveilles d'Asie",
#    ['home_goods_store',
#     'furniture_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJs0aY0jhw5kcRs0D2iLGxNuA': ((48.8388383, 2.303677),
#    -1,
#    'ARC3S',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJXfonYfBu5kcRkTNLzc_By-U': ((48.9018235, 2.3416013),
#    4.1,
#    'Marché Dauphine',
#    ['art_gallery',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJqfwDvClu5kcRAkVCPFhAUIc': ((48.8580698, 2.3294736),
#    4,
#    'Galerie et expertises Cristina Ortega et Michel Dermigny',
#    ['art_gallery',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJPdFgFah65kcRsE4Kz74_8GE': ((48.8488146, 2.275482599999999),
#    -1,
#    'PLACARDS ET CREATION',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJX4KU8wty5kcRR73bLUMItH0': ((48.8507088, 2.3845933),
#    -1,
#    'Atelier Rayssac',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJcSjMRSpu5kcRA1OR-NY412M': ((48.85832990000001, 2.3259362),
#    5,
#    'Silvera Université',
#    ['home_goods_store',
#     'furniture_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJW_ezzAZy5kcRdTLCHWVrfbQ': ((48.8521361, 2.3723442),
#    3.5,
#    'Habitat Paris Faubourg Saint-Antoine',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJzemfseN65kcRDKP4cH95Ngc': ((48.83153780000001, 2.2333914),
#    -1,
#    'BAILLARGÉ LÉONARD Tapissier-Décorateur',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ0YcOqTRu5kcRx-9t525i1NU': ((48.8719004, 2.3237988),
#    4.3,
#    'Faience of Gien',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJL55qIEVu5kcR4GHpYesVk_w': ((48.88534199999999, 2.3384572),
#    -1,
#    'Décoration du Batiment',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJF6_qgy1y5kcRwHf8cOzNQ2s': ((48.81818070000001, 2.3747651),
#    2.5,
#    'Mobalpa Ivry sur Seine',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJeRF4Zopv5kcRLohRk9p0Ztk': ((48.8808124, 2.2790375),
#    5,
#    'BEA FACTORY',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJie2kCBdu5kcR4n5wckrhChQ': ((48.86800390000001, 2.348485),
#    -1,
#    'Soc S K',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJe7nYuJNv5kcRUpEGU682S2A': ((48.8809742, 2.294108599999999),
#    5,
#    'Gala Antiquités Paris 17',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJrQTqexpu5kcRpQ5_SdON5h8': ((48.8656764, 2.3531799),
#    4.8,
#    'Big Shop',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ43BkCuRt5kcR07Xi6L1Xghk': ((48.86980399999999, 2.373913),
#    4.7,
#    'Diva Store Paris 11',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJH4R5E79s5kcRst7_QBuAcm8': ((48.9157865, 2.4433118),
#    -1,
#    'Arat',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJNWAAQclv5kcR7Wwu3VjNqPE': ((48.87309339999999, 2.3165794),
#    4.5,
#    "L'atelier des Chefs Paris Penthièvre",
#    ['food',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJQ3vVbQZy5kcRAnAq91oN_-I': ((48.8509706, 2.375579999999999),
#    4.3,
#    'Societe les Tissandiers France',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJR8LaZ9lx5kcRAdbWb4Bf-K8': ((48.8520573, 2.3369246),
#    3.8,
#    'Natalys',
#    ['lodging',
#     'clothing_store',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJD7i5V_Fu5kcRtxjy4VDR08w': ((48.9020637, 2.3424388),
#    -1,
#    'Gallot Franck',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ0cjlfFlw5kcRCzCbOaBI3J4': ((48.82160260000001, 2.3045179),
#    3,
#    'L EUROPEENNE DE L AMEUBLEMENT',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJi_OGDNxx5kcRxmkSCb0dFjk': ((48.8504154, 2.3389583),
#    -1,
#    'Cappellone Olivier',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJzWNZ0MRt5kcRwgUYRJo94MY': ((48.8827524, 2.3808589),
#    -1,
#    'Codjia Jérôme',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJUenKisdt5kcRp4PSPIGyUAY': ((48.8843322, 2.3916789),
#    1,
#    'LABRADO Concept',
#    ['general_contractor',
#     'plumber',
#     'electrician',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJAQAAR99k5kcRB_gbsjMEi1A': ((48.8743371, 2.2323855),
#    -1,
#    'Shelving and Storage',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ90nF8t5s5kcRUHqonDlXbeQ': ((48.89824240000001, 2.441472),
#    3.4,
#    'Yesmeubles.com',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJRT0dKutt5kcRM-wVt9jh9tE': ((48.8728518, 2.3904598),
#    -1,
#    'Objet Direct',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJfewiAqsS5kcR_PoSMtPcqU4': ((48.85633170000001, 2.4595395),
#    -1,
#    'Longuet Philippe',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJe-O8ppNv5kcRKNxM6d8s30s': ((48.8801666, 2.2939733),
#    4.3,
#    'Mis en Demeure - Bayen',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ8TNMhs8S5kcR-K1NS7uFink': ((48.8818267, 2.4703039),
#    1.2,
#    'HomeSalons',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJxeXNJXlt5kcRS-t_r6luRH8': ((48.8602213, 2.4154439),
#    5,
#    'Ecomeubles Gallieni',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJOyFrhX1t5kcR7_aONPJC-QQ': ((48.855235, 2.4197268),
#    -1,
#    'Worldmobili',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJy5tSxVJu5kcRxJipSjJKZhk': ((48.8886705, 2.325299),
#    -1,
#    'Trancoso Manuel',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJQbYfDgZu5kcRumlximhT9pw': ((48.8650495, 2.3627541),
#    -1,
#    'Expert Art japonais & Kōgei',
#    ['art_gallery',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJFYdXAvpu5kcRnvLOLDZ58OM': ((48.90185389999999, 2.3364692),
#    4.5,
#    'La Trouvaille',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJBcgavZFt5kcRG1aiLAcoiyk': ((48.866901, 2.397497200000001),
#    -1,
#    'débarras brocante',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJeygP1FB65kcRl3sqqjKYRMM': ((48.81266189999999, 2.237431599999999),
#    -1,
#    'Lainé Jean-Christophe',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJZe5LmHNy5kcR-p1tSejrt7o': ((48.8491406, 2.3922143),
#    3,
#    'A La Compagnie Du Placard',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJiUVkrY1l5kcRr6sbszQPm14': ((48.9148541, 2.2732586),
#    -1,
#    "Ambiances D'Intérieur",
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJNUaWTIJv5kcRUZ4lAQs4lCo': ((48.89460080000001, 2.2878749),
#    -1,
#    'Pommart René',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJBedQV8Fx5kcRskVLYu5NMxE': ((48.8409668, 2.3382552),
#    -1,
#    'Bargueños',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ--JM6Spu5kcRc3iM5Y4q7AI': ((48.85817420000001, 2.3239417),
#    -1,
#    'Baudoux',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJV8eK92kN5kcRRBamp3oNVAA': ((48.83834259999999, 2.478703799999999),
#    -1,
#    'Atelier Decoration Richelieu',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJsQcJccUS5kcR81oAESsz8wA': ((48.881789, 2.4714188),
#    1,
#    'Natuzzi',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ-ZOLqiFs5kcRpdP-BWCaRD4': ((48.91358959999999, 2.3747032),
#    -1,
#    'Sdf Meubles De Boutique',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJd1EdghBu5kcRsijs8D3poJc': ((48.8662406, 2.3530974),
#    -1,
#    'Lbs Paris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJNduikjps5kcR1t2uY2ORWxw': ((48.9070542, 2.3846498),
#    -1,
#    'Deger Spma',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJR0Y95WBl5kcR-aGs-bri-hU': ((48.8794693, 2.2752636),
#    5,
#    'Archea Neuilly-sur-Seine',
#    ['furniture_store',
#     'lodging',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJbT4fRNlv5kcRL2LsxT_jFuM': ((48.8609827, 2.3064629),
#    5,
#    'Cousins Sosegh Associés',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJoxIu2zsT5kcRXZTo0JPV_zU': ((48.90798759999999, 2.4763371),
#    -1,
#    'Soc Nouvelle Rebuzzi',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJC_dUd_dt5kcRuwDYsmyU-Og': ((48.8582957, 2.3788713),
#    -1,
#    'Horvath Jean-Claude',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJc3ctsK9l5kcR-QZvDCzEvYY': ((48.906932, 2.245111),
#    4,
#    'GITEM Cuisine - GraniteOnline - UDLM',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ_3PL-EVt5kcRBgJxw8EL4Yg': ((48.86897889999999, 2.4465687),
#    5,
#    'Mercier Tiresias',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJq6o6X7xv5kcRWSl19SH7j0I': ((48.88458300000001, 2.305726),
#    5,
#    'CUISINES DIRECT PARIS/HOME DESIGN 17',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJzXnlsglw5kcRZoAkG_kEx8w': ((48.8448259, 2.27817),
#    4,
#    'Drouault Paris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ-0u6Bo9x5kcR67kavPnaux0': ((48.8756938, 2.3970738),
#    2.5,
#    'Mobeco',
#    ['furniture_store',
#     'lodging',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJq6rWau1x5kcRPUb5CmL4XVU': ((48.8373189, 2.3527488),
#    4.7,
#    'Bureau Vallée',
#    ['electronics_store',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJQcRSLUEN5kcRAvlaw6SubIE': ((48.8364965, 2.4723051),
#    1,
#    'Froment Jacques',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ_bqT-Dpt5kcRpnRTMJFAIRw': ((48.8818344, 2.4455011),
#    -1,
#    'Capitao Manuel',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJsS4n1qd65kcR8xbbZkJzpxg': ((48.8475567, 2.2740246),
#    1.4,
#    "Interior's Paris 16e",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJwy1-Lflt5kcR2pAXLyOL-mY': ((48.8533767, 2.3751638),
#    5,
#    'Cosme Literie',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJA4tuIwRy5kcR3vji6ro2i4s': ((48.8497304, 2.3734147),
#    5,
#    'Nicolas Thibout',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJed4brN5x5kcRO7BLGzITSbI': ((48.851668, 2.338782),
#    5,
#    'Librairie Amélie Sourget',
#    ['book_store',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJXz9oAxZu5kcR6nNXyBVb7II': ((48.849709, 2.370134999999999),
#    -1,
#    'Absolute Office',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJTwcVQfFu5kcR1Puxk1xHWMw': ((48.9027082, 2.341577),
#    -1,
#    'Goldmann Michael',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJxcHo-Axy5kcRkF6Lzaoqzg4': ((48.8494172, 2.3849864),
#    4.5,
#    'Soubrier Antiques and Decor - furniture rental',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ6wbrKBhw5kcR5mLeh0aEKG0': ((48.8473434, 2.296595399999999),
#    5,
#    'Espace Canapés Lits Diva STORE',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJhxbCTSBu5kcRDA8GfOZWYhg': ((48.8591203, 2.3434702),
#    3.5,
#    'Habitat Paris Pont-Neuf',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJFQ07AwZy5kcRZaoeDctdERI': ((48.8511276, 2.377435600000001),
#    -1,
#    'CaraColo',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJawUh9f1s5kcRg3qVBL3u6UU': ((48.89505810000001, 2.4222254),
#    -1,
#    'Bazar Mobilier Deco',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJi8YWG6tv5kcReC7Qchi1VSY': ((48.8940418, 2.3229711),
#    -1,
#    'Instama France',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ04QiZI5v5kcRunAUp_Cie5c': ((48.8832032, 2.2880518),
#    -1,
#    'Menuiserie de Batiment Roux Freres',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ7_K0MFVy5kcRt0fAewr1HSs': ((48.8152493, 2.406705),
#    4.6,
#    'Maximum',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJqeG-iYN65kcRg0AKFxe7Km0': ((48.8242749, 2.2686393),
#    5,
#    'Atelier des Meubles Anciens',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJrypT9RFu5kcR-TAQmQWnIag': ((48.8710966, 2.3555184),
#    -1,
#    'Briemel Jean Ebeniste Jean',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJj0tsGKIS5kcROCoCbqdeE6o': ((48.8589406, 2.4784488),
#    -1,
#    'Plastixia',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJD3fpExpu5kcRSiybsAoxfKQ': ((48.8653168, 2.351654599999999),
#    3.8,
#    'Cinna',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ64BVSNdx5kcReH2Ya8iaqY8': ((48.8518558, 2.3316404),
#    3.6,
#    'BoConcept Paris 6ème - Rue de Rennes',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJH6ZHaalt5kcRbzHOqHflZfE': ((48.8892354, 2.4108359),
#    -1,
#    "L'Ecorce",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJTRwsIotv5kcR3L0U88rB3uM': ((48.8790073, 2.2821327),
#    -1,
#    'Freval',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJhXXSslFu5kcR6n01NNw7wic': ((48.8887009, 2.332925099999999),
#    4.2,
#    'Herbert Emmanuel encadreur',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJdV1XivNv5kcRHRcBovQhjys': ((48.874237, 2.2846081),
#    -1,
#    'N1 du meubles - Home Concept Paris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJT-YvR8Rv5kcRhoPl74S5HDg': ((48.8707489, 2.307915399999999),
#    5,
#    'Office Bureau',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJszgj1CRu5kcRBqUWnypIlYg': ((48.8663543, 2.3367092),
#    -1,
#    'canape cuir Paris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ4YyESulv5kcR8rAl_5q2W5o': ((48.8710844, 2.2952454),
#    5,
#    'PHS PHILIPPE SIRAUD',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJM1pjInVu5kcRzGExIBcqu5Y': ((48.87715919999999, 2.3663859),
#    -1,
#    'Kroliczek Jean',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJy6xrEihu5kcRxbJASiLbiQI': ((48.8574968, 2.332553),
#    -1,
#    'DADA cuisines',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJv9xyhxdw5kcRd9rJdnC1MxY': ((48.84704900000001, 2.2963977),
#    -1,
#    'Topper Meubles',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJiwWOMBpu5kcRYc2hp5_f0UM': ((48.86420380000001, 2.3516598),
#    -1,
#    'Sajuni Et Compagnie',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJb-VdsoNv5kcRUxiHhFsBO70': ((48.8926871, 2.2900464),
#    3.4,
#    'Casa',
#    ['shopping_mall',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJlcSylTJw5kcRWUH_XiXTYGA': ((48.8455781, 2.319598),
#    -1,
#    'Paringer',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJYeLQ6dFx5kcRHR1VEblevmQ': ((48.8473082, 2.328405),
#    5,
#    'Archea Paris 6ème',
#    ['furniture_store',
#     'lodging',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJV_X5kJ1v5kcRk1VwCWDDoDA': ((48.8967198, 2.2952007),
#    -1,
#    'Mauduit Jean-Claude',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJVZMOv1Rl5kcRTruw0YArncQ': ((48.8586933, 2.2729854),
#    -1,
#    'Cera Sa',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJgaCHQ6565kcRHV8IOLyy-IA': ((48.8512178, 2.2672594),
#    -1,
#    'Bergia Le Marois Monique',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJn-qP8bRz5kcR3gAgE5CAjFw': ((48.81314839999999, 2.389722599999999),
#    -1,
#    'Vainglas',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJlyqAIypu5kcRuI24CJQtafc': ((48.858088, 2.3272486),
#    -1,
#    'Moissonnier',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJnX87lgty5kcRy3rDDaREM2w': ((48.8515334, 2.3847069),
#    5,
#    'Rosello Frères',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJn7OMYeJs5kcRDht-ELR3CFE': ((48.8957279, 2.429492999999999),
#    -1,
#    "Cap'projets",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJW2DEatlx5kcRQuVyORFYQ38': ((48.85260239999999, 2.3369271),
#    3.8,
#    'La Joie de Vivre',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJKYeUHgtv5kcRAHYgeQN5y-0': ((48.9000482, 2.3048518),
#    -1,
#    'Atelier Cézario Padouck',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJc1nyVoNt5kcRO02_6rFk9RY': ((48.8648845, 2.4078476),
#    -1,
#    'Ammour Mouloud',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJL6C5P3Ny5kcRzeXDmZef-98': ((48.8488219, 2.3900713),
#    4.5,
#    "L'EDITO",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJnQYiZ6xy5kcRfYLYGpn4_6Y': ((48.8478984, 2.4529124),
#    -1,
#    'L2C',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJvSQRYKV65kcRZp7DHv3KUYY': ((48.8476593, 2.2666206),
#    5,
#    'Relookitchen',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJg_eTExpu5kcRkSoDVE7UpEg': ((48.8654642, 2.3524699),
#    1,
#    'Ory Toons',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJsbkQiM8S5kcR2hNjGWNPr6k': ((48.8820905, 2.4698287),
#    -1,
#    'Calligaris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJfbOy0DJy5kcRCmb5DtXtf2I': ((48.8160663, 2.376952499999999),
#    -1,
#    'SIG Distribution',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJA244uM5t5kcRlAT91EvzJp4': ((48.8894843, 2.3858242),
#    -1,
#    "L'état de sièges",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJwfttrMUS5kcRXj0hmO-A5YU': ((48.8819258, 2.470052899999999),
#    2.1,
#    'Cuisines AvivA Rosny-sous-bois',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJw4ONwWJt5kcRZx_G5l8O5Ac': ((48.856164, 2.424718),
#    -1,
#    'Habitat Ameublement Social',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJZ-xzmEFu5kcRPXETvXN37sw': ((48.880195, 2.3441681),
#    -1,
#    'Rabillé Christophe',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJA5wU3VFk5kcRUKtwy4Yezak': ((48.90780519999999, 2.2303625),
#    2.4,
#    'Dépôt 1 Conforama Colombes',
#    ['storage',
#     'electronics_store',
#     'lodging',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ44zDF8YS5kcROOebbDUbD5Q': ((48.8775681, 2.4708559),
#    -1,
#    'Distri.mob',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJzSijSsRv5kcRJCxWCW6M0NE': ((48.8707505, 2.3090224),
#    -1,
#    'Mooti',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ5_Py-VZt5kcRWFMfbedgfNg': ((48.82560739999999, 2.3326773),
#    -1,
#    "L'odyssee.",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJMfu8ppNv5kcR3asKt9NgDNo': ((48.88083200000001, 2.2931952),
#    -1,
#    'IHT',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ4WdJwHBw5kcRr4uP6_W52EU': ((48.8286753, 2.281759),
#    -1,
#    'Micadho',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJwTZs_VJ85kcRDAbYguWcCUA': ((48.87558360000001, 2.3022004),
#    -1,
#    'iNDEXoFdESiGN',
#    ['art_gallery',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJD9uGrmZv5kcRewjYR2vDPSs': ((48.91342100000001, 2.2876218),
#    5,
#    'Guegan Et Fils',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJrR41qwRu5kcRiFyJX4bI_8g': ((48.861251, 2.356124),
#    -1,
#    'Perrine Rousseau Paris',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJBaDtc11u5kcR1GHbNjImbdA': ((48.888569, 2.346001),
#    -1,
#    'Bourbon Mobilier Collectivités B.M.C',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJNfyluxNw5kcRM9aL3g7hJNs': ((48.8403607, 2.2903853),
#    -1,
#    'Futon Santé',
#    ['lodging',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ24vyAbZx5kcR5OG94n5HJ3g': ((48.8363711, 2.3263093),
#    5,
#    'Happy Home',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJn9Y-RsQS5kcRPhwU-w9-okg': ((48.88140169999999, 2.471230799999999),
#    1.1,
#    "Château d'Ax",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ7fRuTPFu5kcR-CTdgdN359M': ((48.9041338, 2.338812700000001),
#    -1,
#    'AU TRESORANTIC',
#    ['jewelry_store',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJo53z30Bw5kcR4QL85kKfH5Q': ((48.8348658, 2.3017764),
#    -1,
#    "Feuille d'Or et Mercure",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ_8DXXvxy5kcR80fbtNYfIcw': ((48.8179635, 2.4169518),
#    -1,
#    'Grandes Cuisines',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJaxFJxlBu5kcRASwqgP6Y0ds': ((48.890916, 2.334338),
#    4,
#    'Chez Will',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJzfkRI49y5kcRnCTPdOWsTkA': ((48.8426406, 2.4175737),
#    -1,
#    'Shoe Case',
#    ['furniture_store',
#     'lodging',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJY5yHS9Jx5kcRuthPZ16TFvM': ((48.8489684, 2.3250528),
#    4.4,
#    'Cherche Midi Droguerie - Bricolage - Cuisine. Ancienne Maison Raclin',
#    ['hardware_store',
#     'health',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJUWyzIrRx5kcRnhxqvyCQDbo': ((48.8329268, 2.3250928),
#    2.3,
#    'Bambins Déco',
#    ['lodging',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJF4ck5gNz5kcRliLpZ4lVdxs': ((48.81049549999999, 2.4144107),
#    -1,
#    'Lambert Françoise',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJhUE40zts5kcRCAH-JOFwbGI': ((48.908272, 2.387748),
#    5,
#    'Meubeo',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ04Rwpmdy5kcR8vsbjmBSllU': ((48.8366863, 2.401537),
#    -1,
#    'Meubles Bois Exotiques',
#    ['furniture_store',
#     'natural_feature',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJi5dKdg5w5kcRP1waC_Yg61M': ((48.8424878, 2.285231),
#    5,
#    'Archea Paris 15ème',
#    ['furniture_store',
#     'lodging',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ2VDZkXVx5kcRBw9NwNhVcNo': ((48.8153063, 2.3448081),
#    -1,
#    'Armelle P Créations',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJkR4JHUtu5kcRnMumEf7vBkA': ((48.87932099999999, 2.3258283),
#    -1,
#    'Design & Conseil',
#    ['furniture_store',
#     'general_contractor',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ890bQo5v5kcRDia9mrG3FPc': ((48.8840152, 2.2892463),
#    -1,
#    'Surfaces et Cuisines',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJF0jVhMdt5kcRjbljktHE3do': ((48.8834357, 2.3910338),
#    -1,
#    'Broquantic',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJM2m3OzFw5kcRBPAg-LFLReA': ((48.842532, 2.3133454),
#    -1,
#    'Décoration tapisserie Henriette Trejtnar',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ73ZcCdVy5kcRsu9zgWlUiKs': ((48.8153375, 2.4507554),
#    -1,
#    'Atelier Robert Leyx',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJS_BX1gdu5kcRBsan5Kp-AgY': ((48.8657841, 2.3655813),
#    3,
#    'MOB CUISINES',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJrT6pZ6Vl5kcRKJ8wUbk9w4A': ((48.907136, 2.248054),
#    5,
#    'Domeau Pérès',
#    ['art_gallery',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJUW-REfJt5kcRL3yxzDVCdQ0': ((48.8647936, 2.3857432),
#    -1,
#    'Groupe Paris Meuble',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJExedMLNv5kcRU6Otdh-Txaw': ((48.8834683, 2.3230932),
#    -1,
#    'Métisse',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJNxLty6J65kcRJzINSsZBO0M': ((48.8392628, 2.2652968),
#    -1,
#    'Evrard Jeanne',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJR5pLcGNw5kcRaKOYXRSDMRs': ((48.8212589, 2.287617),
#    -1,
#    'OSM France',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJk07sE4Vv5kcRyTBwOHMbZ6g': ((48.8890717, 2.2890026),
#    5,
#    'Patrick Pierre Ebénisterie',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJUc8PJTtz5kcRcsDXCsJEFlk': ((48.8774451, 2.435592),
#    4.5,
#    'EASY CUISINE',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ86EOa0Vu5kcRvlRQLtziehM': ((48.87063, 2.346829),
#    -1,
#    "L'Atelier MARINKA",
#    ['real_estate_agency',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJqx0qhh1w5kcRfzGtOn-D7tU': ((48.8571044, 2.2918654),
#    -1,
#    'V2',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJvzhsYphx5kcRUliF7DXtBVw': ((48.8234325, 2.342773499999999),
#    -1,
#    'Billard Stephan Matthew',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ8TaTQ0tu5kcRSWPDRguy3xQ': ((48.8809347, 2.3250902),
#    -1,
#    'CAD Couture',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJiV_Ao2xw5kcRs290usgpIv0': ((48.8361198, 2.2916682),
#    5,
#    'Elles Décorent',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJif1JKpNv5kcRlgpxjl45Zh0': ((48.8775562, 2.2929025),
#    1,
#    'Antiquités la Marotte',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJWVkrrkds5kcR4ksWlqL6-6k': ((48.9071933, 2.3955911),
#    3,
#    'Futur Meuble 2015',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJCfeAQLdx5kcRuisb1N60G1k': ((48.8321419, 2.3302858),
#    -1,
#    'Atelier Bis',
#    ['general_contractor',
#     'lodging',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJP_4BEaxv5kcRZeCG3BFFdpM': ((48.8911611, 2.3202051),
#    -1,
#    'Zinck Alain',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJpfUELZBu5kcRMbWgq_WwzhE': ((48.9070686, 2.3578582),
#    -1,
#    'Soc Sauvel',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJVYsCqw5y5kcRhvJCqka3KoE': ((48.85057459999999, 2.3839313),
#    4.3,
#    'Citeaux Mural',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJDZPep4lt5kcR_c5zNpIJNhw': ((48.8575679, 2.3972748),
#    -1,
#    'Boat Safran.creation Sophie Lescot',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJpbQGhW5l5kcRdkmkYJ5ZNwc': ((48.8851473, 2.2630829),
#    5,
#    'Durififi',
#    ['clothing_store',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJBybmmA9v5kcRtSpHwOVcnlg': ((48.9050597, 2.3131036),
#    -1,
#    'C.c.b',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJKZeNzTtu5kcRJ8CH_0WSnVQ': ((48.870485, 2.337686),
#    -1,
#    'Fil et Matière',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJKYHem3Zu5kcRy-e8pjCptMg': ((48.8810941, 2.3654594),
#    -1,
#    'Ligne et Couleur',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ6aicbNZx5kcRkbID0ip3oKw': ((48.85522220000001, 2.3285074),
#    -1,
#    'Société D et P',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJU7uMIepx5kcRe86M6c3-9Hg': ((48.8410227, 2.344629),
#    5,
#    'Thyrse Paris - tapissier décorateur',
#    ['general_contractor',
#     'furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ3dmfheFt5kcRUzzbdQDQqQQ': ((48.8712737, 2.3703904),
#    -1,
#    "La Companie Limitee'des Confort Meubles",
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJtXm9AgJu5kcR9r0bLjfxtyU': ((48.85996850000001, 2.3609881),
#    -1,
#    'Cuisines Milet',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJV46OHZRv5kcR8lj4A5EoHkI': ((48.8811517, 2.288734),
#    -1,
#    'Roche Jean-Paul :atelier de la methode ancienne',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJWc7M79Rx5kcRubY46-9GuJk': ((48.85346219999999, 2.3238394),
#    -1,
#    'La Paresse en Douce',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJ74Vi6WJw5kcR2tFFxUrdtBs': ((48.8186529, 2.2867943),
#    -1,
#    'Lajnef Najah',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJxQwb62Vy5kcRdY5oGE38xvY': ((48.84073899999999, 2.4006369),
#    -1,
#    'Société Gérard Conte',
#    ['furniture_store',
#     'home_goods_store',
#     'store',
# ...
#    -1),
#   'ChIJ4dnixz1w5kcREMHCJwRMXco': ((48.8433432, 2.3005754),
#    4.8,
#    'Pizza de Vinci',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ2TEJ4fpv5kcRkgLCnAvc1sg': ((48.86509840000001, 2.2874038),
#    -1,
#    'La Colère du Gorille',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ8-FJlpR65kcROsUWewl3qnk': ((48.8336625, 2.2543172),
#    4.3,
#    'Aveyron Café',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJlwJFUZ5x5kcRK_wN4FlOEhM': ((48.8181153, 2.3445216),
#    -1,
#    "Autour de l'Evènement",
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJiT2GNW9u5kcRwGQMOPO8pXY': ((48.8849374, 2.3531949),
#    5,
#    'Stef Silini Hocine et Hariti Yvonne',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJE47cw7Bx5kcRE1wyUlNV35I': ((48.8302615, 2.3293049),
#    -1,
#    'Bellec Et Compagnie',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJR8Hlz3Rw5kcRi_ecELef1cQ': ((48.84319910000001, 2.2777848),
#    4.2,
#    'Balardis',
#    ['supermarket',
#     'bakery',
#     'bar',
#     'grocery_or_supermarket',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJJUwrjhZu5kcRMCIWYePRS70': ((48.870893, 2.349603),
#    3.6,
#    'Delaville Café',
#    ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJn9z214Jy5kcRxUtYRZ23Yio': ((48.8521502, 2.422186200000001),
#    -1,
#    'Sci Du 14 Bld De Courcelles',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ-TdAKGlv5kcRAuPB5Cm6XeA': ((48.91315, 2.2957785),
#    4.7,
#    'Le Petit Vatel',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJqUG-j2Vv5kcRthzZK9OXziI': ((48.9108813, 2.2921341),
#    3.9,
#    'Les Victoires',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJJV6PvXh65kcRL35SYn8AlsI': ((48.81116060000001, 2.272580099999999),
#    4,
#    'Café du Marché',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJwyI9-fJt5kcRQEJZ0SeWxEU': ((48.8632838, 2.3874483),
#    4.7,
#    'Bar & Beer',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJUzF3Nw1u5kcRZ2oHcns9qak': ((48.875523, 2.358897999999999),
#    4.5,
#    'La Vigne Saint Laurent',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJbY716vVu5kcRIe-FcZbnND0': ((48.8977031, 2.343493899999999),
#    -1,
#    "L'endroit bar",
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJK4eH0lgN5kcRuq-SLQ_1oTE': ((48.8516178, 2.4732927),
#    3.6,
#    'Café le Trasmontano',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJnybkU0lw5kcRTlAPOjx3LkU': ((48.831989, 2.314049),
#    3.6,
#    'Le Café Chineur',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJayKywX9y5kcRSBC-00Gyt08': ((48.8536079, 2.4101363),
#    5,
#    'Ucar Sadik',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJi60GBWFl5kcRXGgwX9B9AvU': ((48.8807303, 2.2758403),
#    3.4,
#    'Durand Dupont',
#    ['restaurant',
#     'bar',
#     'night_club',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJj1Ey7ABt5kcRVs7kNrOq0nI': ((48.8915735, 2.4167348),
#    4.1,
#    'Le Courtois',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJSScKdKNy5kcRL2TrMh7n89g': ((48.8464032, 2.437989),
#    4.4,
#    'RI Xin',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJmRn4nP1u5kcRaTu3ES1ZcQ4': ((48.9042521, 2.326862),
#    3,
#    'Soltani Mohammed',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJLwzedtl65kcRPOLTVNRp-XI': ((48.8455074, 2.2359449),
#    -1,
#    'Huc Jean-Paul',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJsy_HJYZx5kcRjSuNgzzMKZg': ((48.8253485, 2.3608267),
#    4.3,
#    'La Caravelle Saigon',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJL6uwB2pw5kcRQTMflbYaivs': ((48.8325289, 2.2972913),
#    3,
#    'Wass Food',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJF2zstEBt5kcRWCa1ZxL49us': ((48.8733224, 2.4414581),
#    4.1,
#    'LA FONTAINE DU BROUILLARD',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ06_19Qtu5kcRHLuMfKXkUZk': ((48.8719, 2.362679),
#    4.4,
#    'Le Cinquante',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJb5tvwXFu5kcRSSlsXMNpYAw': ((48.8825625, 2.3590752),
#    -1,
#    'Vino',
#    ['bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJlfwLT4V65kcRtWMs3f7UhmA': ((48.82703850000001, 2.2641679),
#    -1,
#    'Tout Va Mieux Louis Deux Mille',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ757ovBJw5kcRDYqzd-gYh40': ((48.83828800000001, 2.2875932),
#    2.5,
#    'Sakura 88',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJZVkrw_Jw5kcR3sY9p18ZA9k': ((48.80887629999999, 2.2965781),
#    4.3,
#    'Piccolo Dino',
#    ['meal_takeaway',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJYbkvr-Bt5kcRis7ma7mCHWk': ((48.8754344, 2.3736599),
#    4,
#    "Monkey's",
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJB0PmVzxu5kcRTJ3Yu5o77Kk': ((48.8687978, 2.3421441),
#    4.1,
#    'Brasserie Gallopin',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJpRrWogdu5kcRRJp5xP0v4bw': ((48.8639492, 2.3659536),
#    4.1,
#    '1K Paris',
#    ['bar',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJhXXC68Js5kcRYY9FaFZz58Y': ((48.9054454, 2.4402408),
#    -1,
#    'Saloon Pub',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJZWpDJ-pt5kcRUqElZIxDYg8': ((48.8738007, 2.3853093),
#    3.6,
#    'Le Métro Pyrénées',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJKZeh8SFu5kcRAtH-OJUKadk': ((48.8607762, 2.3438623),
#    3.8,
#    "Le N'Importe Quoi",
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJU7kAw1hu5kcRH1U5QcJl8LA': ((48.8951026, 2.3410907),
#    4,
#    'Flavours of the Tropics Gabonese Restaurant',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJi1v8jFhu5kcRajgqGnw_Bik': ((48.895481, 2.3397758),
#    -1,
#    'Bar Paradis Du poteau Brasserie',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ6RJHKYBv5kcRTWy0Ko_mfsw': ((48.8975509, 2.2826685),
#    3.6,
#    "Ambiance d'à Côté",
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJE_Nn8ehv5kcRKulA07Q5NPE': ((48.8689171, 2.2973641),
#    3.8,
#    "L'Ardoise",
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJgX96kxhu5kcR6cF3n0CBpec': ((48.8855182, 2.3422353),
#    4.1,
#    "Corcoran's Sacré-Cœur",
#    ['bar',
#     'night_club',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJV6gU61MN5kcRxgNgyzaOEA0': ((48.84772539999999, 2.4605867),
#    4.6,
#    'Le Timgad',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJzcmzzGly5kcRownxlzPMT9I': ((48.8359526, 2.3962789),
#    -1,
#    'Quarante trois',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJQUb836cS5kcRoc-3bQRhNdU': ((48.85493719999999, 2.4681352),
#    4.7,
#    'Le Routiers des Amis',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJtRDl8uFk5kcRUcwT9WsASOg': ((48.8829851, 2.2330205),
#    4.3,
#    'Tabac de la Gare',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ99VrKcJv5kcR2WtwYIY4oOQ': ((48.8722325, 2.3035258),
#    4.4,
#    'Hotel Lancaster',
#    ['bar',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJyxYeB6hl5kcRsBLuR401ecA': ((48.8987735, 2.2464286),
#    -1,
#    'Timothee',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJE_JG49Bt5kcR7kdsvF5T-ko': ((48.88717499999999, 2.3749483),
#    4.3,
#    'Péniche Antipode',
#    ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJH_pAExty5kcRKU-prZzCgo4': ((48.8441369, 2.372446),
#    3.7,
#    'Gamma Café',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJjSV9Pc9x5kcRdvc0tnet8gU': ((48.842644, 2.330171999999999),
#    4.6,
#    'Toyo',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJa3UAl39x5kcRoDSjPIZvAMw': ((48.8145053, 2.361439400000001),
#    1.7,
#    "L'Orangeraie du KB",
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJIzpIql5w5kcRPvR2p5XpHy4': ((48.8217116, 2.3020022),
#    -1,
#    'Cheng',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ94oMRN1x5kcR8vRkVRabnIE': ((48.8470996, 2.3427509),
#    3.5,
#    'Le Soufflot',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJIbG5j6tt5kcRXavlSZ513gw': ((48.8919088, 2.4099544),
#    -1,
#    'Bar Tabac',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJm1N0IoRv5kcRBXg6Ymu2foY': ((48.891443, 2.2858525),
#    2.3,
#    'Tobacco Celtic (open throughout the month of August 2017)',
#    ['cafe', 'bar', 'food', 'store', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJJbKRX_ly5kcRMj3P_SELhdw': ((48.82070410000001, 2.414503),
#    4.2,
#    'Yumis',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ38gsE_pt5kcRdE7jhi164r4': ((48.8617702, 2.3778849),
#    4.6,
#    'Vertigo',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJUTfgYXRu5kcRN4fEzpAxHuY': ((48.8784856, 2.3642366),
#    4.1,
#    'Casa Roma',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJebE0N8Vv5kcRxZzKB76275o': ((48.8675135, 2.3097819),
#    3.5,
#    'Le Victory',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJyTM2z-Jx5kcREjW4IAFYiR0': ((48.85471920000001, 2.354726400000001),
#    3.9,
#    'Café-Restaurant Louis Philippe',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJsRsXq-dx5kcRRPN0Smfhr1Y': ((48.848415, 2.346515),
#    4.1,
#    'Le Petit Prince de Paris',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJuesvixZy5kcRrg4xCoy9nhc': ((48.8381759, 2.3807368),
#    -1,
#    'Le Papa Cabane',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJK8wYprNv5kcRdrxhraipOwg': ((48.88363649999999, 2.3211714),
#    4.3,
#    'O CUBE',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJfy7g01pu5kcR-sGS7srWCYA': ((48.88684029999999, 2.338187),
#    4.7,
#    'La Boite aux Lettres',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJpYXINilt5kcRDIgRD05fXwI': ((48.8897169, 2.4526133),
#    3.4,
#    'Le Celtic Noisy',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJD55B_qxv5kcRGbqAGjwiwfI': ((48.88967599999999, 2.322237899999999),
#    4.2,
#    'Mawal',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJIzKbTNRt5kcRJK-VzuDq_D4': ((48.8925044, 2.3729244),
#    4.5,
#    'Gouraya (Le)',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ8R5tH1Fu5kcR2XQlATxyDKM': ((48.8903736, 2.3328924),
#    4.3,
#    'Ētsi',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJgQzl8iJs5kcRUURzbBPX-No': ((48.914565, 2.380837),
#    2,
#    'Ould Slimane Rabah Ould Slimane Male',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJy4oFvJFt5kcRS6uGPvV9iEo': ((48.8668162, 2.397694099999999),
#    4.3,
#    'La Limite',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ2yMsjUpw5kcREO2ssPwsGys': ((48.8352487, 2.318030299999999),
#    4.5,
#    'Utopia',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ3fBFg7Vz5kcRFDxbUMq1GWc': ((48.81201669999999, 2.386390099999999),
#    3.6,
#    'Café de la Mairie',
#    ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJzUVX8XRu5kcR-EWo83asJy0': ((48.8781474, 2.3647457),
#    4,
#    'Les Caves Béarnaises',
#    ['bar', 'lodging', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJXUM2f-lv5kcRe6ioclGNPJU': ((48.87191149999999, 2.2979366),
#    -1,
#    'Jaipur',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJQVdMZPhu5kcRF4O2i4A2tk4': ((48.89752839999999, 2.3343106),
#    -1,
#    'Boyer Thierry',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ83MJdgFy5kcR595wur1Undg': ((48.8515628, 2.3694715),
#    3.7,
#    'Les Associés',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJP_Nx88Vv5kcR7GvKxcnL-h4': ((48.8708755, 2.3114579),
#    3.9,
#    "L'Empire du 8eme",
#    ['bar',
#     'night_club',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJe82yBe565kcRw_4M-iq_6jg': ((48.8284305, 2.246218),
#    3.7,
#    'Shanghai',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJRXyeXpxt5kcRdhMuZWXO0Mk': ((48.8677984, 2.4086096),
#    3.3,
#    'La Lorraine',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJHZpFMSlt5kcRoNJX9B9cco8': ((48.8895978, 2.4524519),
#    -1,
#    'Bar Du Siècle',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJv6p75uRy5kcRXGoCFiHPofc': ((48.8213511, 2.4220803),
#    2.6,
#    'Le Village',
#    ['bar',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJFSkx11ty5kcRBRckKrpkmSQ': ((48.8278668, 2.4035391),
#    4.6,
#    'Chez René et Gabin by Sasha',
#    ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJl5_tY5Jw5kcRmuzeJz-evf4': ((48.8060743, 2.2923536),
#    3,
#    'Le Monde En Marche',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJr2V4DeZt5kcRAR5pLxmiQlQ': ((48.871239, 2.3781827),
#    3.7,
#    'Tunis-Tunis',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJLVAreoN65kcRI9L2G-gIwFY': ((48.8253871, 2.2694653),
#    -1,
#    'RVF',
#    ['bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJIV4vxTxt5kcRGo8hWaAKj6k': ((48.8832595, 2.4383098),
#    5,
#    'Zhang Romainville',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJnbCo8ZVt5kcR3bDt9vajiJs': ((48.8748522, 2.3956614),
#    4.9,
#    'Le Mercure',
#    ['restaurant',
#     'cafe',
#     'meal_takeaway',
#     'bar',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    -1),
#   'ChIJS2pWgb1t5kcR6eGuadeZS1E': ((48.8756753, 2.3991609),
#    3.7,
#    'Oualikene Abdelkrim',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ2zbmvOps5kcRbQQ8du1TiAU': ((48.91350659999999, 2.4385393),
#    -1,
#    'Scoop',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJ-275b6hx5kcRHQ27eFx-abY': ((48.8181508, 2.3299631),
#    3.8,
#    'Le Grand Mandarin de Montrouge',
#    ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJkaPzAft65kcRGR-QpdtTaH8': ((48.82742400000001, 2.234898400000001),
#    3.5,
#    'Café Seguin',
#    ['restaurant', 'cafe', 'bar', 'food', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJqUmXsvx65kcRPY9M62WQgQI': ((48.8282467, 2.2344076),
#    -1,
#    'Meatpacking Distrcit',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   'ChIJuVBI63hx5kcR14F2QvQUMLY': ((48.8144369, 2.3561714),
#    -1,
#    'Medjo Abel',
#    ['bar', 'point_of_interest', 'establishment'],
#    -1),
#   ...}}

# %%
poidata["furniture_store"]
# Out:
# {'ChIJvQW3LzBu5kcR1K1RinPHWuo': ((48.86663159999999, 2.3316366),
#   2.2,
#   'Unopiu',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJPa034vBu5kcRgPhYMUxo0Dk': ((48.90328890000001, 2.339881399999999),
#   -1,
#   'Olivier Hutzemakers',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJS2paJgVy5kcRsWnyhE-Ng4Y': ((48.84763299999999, 2.3753779),
#   -1,
#   'Téodor',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ5_Q5YZRv5kcRs3k9SIdrmtM': ((48.8798415, 2.2971538),
#   5,
#   'Féau and Co.',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJvw0d809w5kcRvg7fJrlayzE': ((48.8279332, 2.3090737),
#   -1,
#   'Patoux Florence Marie-therese',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ86G-5alt5kcRtPN69Wx3nsA': ((48.8890514, 2.4137347),
#   1,
#   'Au Salon Du Meuble',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJI8hEZT1w5kcRwuzXQpYW5mg': ((48.8450829, 2.3001058),
#   3.6,
#   'Bricorama',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJG2Jx6YBx5kcRt01WAbgdvys': ((48.8189954, 2.3616023),
#   -1,
#   'Fachan Robert',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJq6q2OZ5l5kcRBJAOq9Z2m-k': ((48.8992709, 2.2618424),
#   3.8,
#   'Cuisines Références',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ1T7hEUJu5kcRY-n7-sBacX4': ((48.8821368, 2.3458452),
#   4.8,
#   'Krea 99',
#   ['jewelry_store',
#    'clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJZwozmhJv5kcR61nTA-AHEAY': ((48.908004, 2.3051652),
#   5,
#   'Pashev Entreprise',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJmYBrpJ1y5kcRQ7DfxvAWahI': ((48.85284710000001, 2.4262186),
#   -1,
#   'Oudia Noureddine',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJo-lF1uxt5kcRONVgWod9KDw': ((48.867983, 2.389954),
#   3.7,
#   'BedUp® Paris 20',
#   ['general_contractor',
#    'lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJqXZdTnNy5kcRF45WLS14qxI': ((48.84958499999999, 2.3893007),
#   -1,
#   'A.M.S Agencement Menuiserie Services',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJwbOsxBdw5kcRr7RQbH1oGbA': ((48.84558399999999, 2.2979308),
#   2.3,
#   'Cuisines CORMIER - Cuisines & Agencements haut de gamme',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJcbDaUgpv5kcRZoXp6oW4IBc': ((48.899718, 2.306318),
#   3.6,
#   'Bricorama',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQ6gKTqJy5kcRpfTC7LTcJDI': ((48.84754979999999, 2.4362183),
#   -1,
#   'Atelier du 15',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJa7EkMAly5kcR0EfZGyKx3X4': ((48.8509994, 2.3814537),
#   4.9,
#   'Les Chi(n)euses',
#   ['store',
#    'furniture_store',
#    'home_goods_store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJFXEB7E1y5kcRusfa4-Y-nV4': ((48.8190679, 2.396562799999999),
#   -1,
#   '26 Dream Meubles',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJEVLT0AFy5kcRE7-nvEBZJb4': ((48.8527552, 2.3670081),
#   3.6,
#   'Scandilodge',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJx6_Hkwlt5kcRRs2hXfP-z5U': ((48.880785, 2.4156019),
#   -1,
#   'Eberlin Pierre (Ets)',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJBad8B1Vl5kcRGmitUT92u6I': ((48.8600506, 2.2750157),
#   -1,
#   'DAUMAL',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ8-PAy2du5kcRKH26ELc-aHg': ((48.88811309999999, 2.349367299999999),
#   5,
#   'Romano Décoration',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJE8Xm279v5kcRuVlQg6l5EcA': ((48.878936, 2.301325),
#   5,
#   'Victoria Créations',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJISIuqAVu5kcR42E9Puf6YHs': ((48.8709753, 2.3353917),
#   4.8,
#   'UBER-MODERN',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJn9Y-RsQS5kcR_NDYWXkwRmU': ((48.8820854, 2.4698289),
#   3,
#   'Flexa',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJqwPa-cBv5kcR4rATgBR3zjU': ((48.87527069999999, 2.304111799999999),
#   5,
#   'Somon Franck',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ_4K01VRl5kcRZNAgo0oa33w': ((48.8579326, 2.2742123),
#   3.8,
#   'La Chaise Longue',
#   ['home_goods_store',
#    'department_store',
#    'furniture_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJaXidpSly5kcRcIqhJjxD_PA': ((48.8226948, 2.3664403),
#   4.2,
#   'Art Saigon',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJOYdu4Od65kcRthZ0B4Qx6FU': ((48.8661974, 2.2816399),
#   5,
#   'Open en Ville',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJIXl-lXhv5kcR3fa1QNJ9AvE': ((48.8987191, 2.2875468),
#   -1,
#   'Dimex',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJJ8sKLyBu5kcRZgp_hXvDSQ4': ((48.8582592, 2.3440777),
#   -1,
#   'Manila Management et Finances',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJoyaONXNt5kcRaRASsOoXrBE': ((48.8745531, 2.4205067),
#   5,
#   'LA MARBRERIE CONTEMPORAINE',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJjUtEmBZy5kcRX6BklYe5Gag': ((48.838959, 2.381748),
#   -1,
#   'Bertothi',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJlWzQWhdw5kcRq_5lpMHffDs': ((48.84658030000001, 2.2939568),
#   -1,
#   'Bouillon Dominique',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJLf6x2Ndx5kcRO5USy-44coY': ((48.8566039, 2.3310984),
#   -1,
#   'Galerie Marc PHILIPPE',
#   ['art_gallery',
#    'museum',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ8Uo6Tepv5kcRzqXQEXBCBos': ((48.87385399999999, 2.29824),
#   3.6,
#   'Veneta Cucine Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJjdhWEBdw5kcRWdTnkdKGSQo': ((48.84526899999999, 2.294894),
#   -1,
#   'FABRY Sarl',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJm2sGGhdu5kcRrj70syaz76M': ((48.8681022, 2.3492682),
#   5,
#   'Rouxel SAS',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJHfZSv9Jz5kcRW868QG8YFYA': ((48.8143793, 2.3733026),
#   -1,
#   'Espace Cuisines Truffy',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJS-W477Jl5kcRWBtBlnSisss': ((48.9104743, 2.2394028),
#   -1,
#   'Maugendre Renan',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ-eaANY1t5kcRYR7lELOhK4U': ((48.8643207, 2.3905845),
#   3.7,
#   'Déco Stores',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJl4oRRAhl5kcRdOuWb7Z_a1A': ((48.8968296, 2.2484363),
#   3.1,
#   'Mobalpa Courbevoie',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJE342EA1t5kcRyDvFosAPiyU': ((48.8766779, 2.4228877),
#   1,
#   'Matchef',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJobDQhKRx5kcRUFCOTPO0caY': ((48.867537, 2.377186),
#   5,
#   'STEEL LOFT by TITIETSEB MOBILIER INDUSTRIEL',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ9_STJfxt5kcRHIaGSFk8axo': ((48.8611292, 2.3709343),
#   -1,
#   'ouma productions',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJPyZQ6ilu5kcRxf77fPjbkz4': ((48.8575721, 2.3289435),
#   5,
#   'Galerie Bazin',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJceDAIGoN5kcRhZywfkjQ4DA': ((48.8384584, 2.4793303),
#   -1,
#   'CFB Concept Aménag Décoration Rénov',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJFQSVnNJx5kcRuPzuSdrji_Y': ((48.84670029999999, 2.3234409),
#   -1,
#   'Serendipity',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJobQxxllu5kcRtqywjGd91PQ': ((48.8933271, 2.3374723),
#   -1,
#   'Chaouat Charles',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJp8YK1Idx5kcR58rNzTppBxA': ((48.82541459999999, 2.3617571),
#   4,
#   "Aux Merveilles d'Asie",
#   ['home_goods_store',
#    'furniture_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJs0aY0jhw5kcRs0D2iLGxNuA': ((48.8388383, 2.303677),
#   -1,
#   'ARC3S',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJXfonYfBu5kcRkTNLzc_By-U': ((48.9018235, 2.3416013),
#   4.1,
#   'Marché Dauphine',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJqfwDvClu5kcRAkVCPFhAUIc': ((48.8580698, 2.3294736),
#   4,
#   'Galerie et expertises Cristina Ortega et Michel Dermigny',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJPdFgFah65kcRsE4Kz74_8GE': ((48.8488146, 2.275482599999999),
#   -1,
#   'PLACARDS ET CREATION',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJX4KU8wty5kcRR73bLUMItH0': ((48.8507088, 2.3845933),
#   -1,
#   'Atelier Rayssac',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJcSjMRSpu5kcRA1OR-NY412M': ((48.85832990000001, 2.3259362),
#   5,
#   'Silvera Université',
#   ['home_goods_store',
#    'furniture_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJW_ezzAZy5kcRdTLCHWVrfbQ': ((48.8521361, 2.3723442),
#   3.5,
#   'Habitat Paris Faubourg Saint-Antoine',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJzemfseN65kcRDKP4cH95Ngc': ((48.83153780000001, 2.2333914),
#   -1,
#   'BAILLARGÉ LÉONARD Tapissier-Décorateur',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ0YcOqTRu5kcRx-9t525i1NU': ((48.8719004, 2.3237988),
#   4.3,
#   'Faience of Gien',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJL55qIEVu5kcR4GHpYesVk_w': ((48.88534199999999, 2.3384572),
#   -1,
#   'Décoration du Batiment',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJF6_qgy1y5kcRwHf8cOzNQ2s': ((48.81818070000001, 2.3747651),
#   2.5,
#   'Mobalpa Ivry sur Seine',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJeRF4Zopv5kcRLohRk9p0Ztk': ((48.8808124, 2.2790375),
#   5,
#   'BEA FACTORY',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJie2kCBdu5kcR4n5wckrhChQ': ((48.86800390000001, 2.348485),
#   -1,
#   'Soc S K',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJe7nYuJNv5kcRUpEGU682S2A': ((48.8809742, 2.294108599999999),
#   5,
#   'Gala Antiquités Paris 17',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJrQTqexpu5kcRpQ5_SdON5h8': ((48.8656764, 2.3531799),
#   4.8,
#   'Big Shop',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ43BkCuRt5kcR07Xi6L1Xghk': ((48.86980399999999, 2.373913),
#   4.7,
#   'Diva Store Paris 11',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJH4R5E79s5kcRst7_QBuAcm8': ((48.9157865, 2.4433118),
#   -1,
#   'Arat',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJNWAAQclv5kcR7Wwu3VjNqPE': ((48.87309339999999, 2.3165794),
#   4.5,
#   "L'atelier des Chefs Paris Penthièvre",
#   ['food',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQ3vVbQZy5kcRAnAq91oN_-I': ((48.8509706, 2.375579999999999),
#   4.3,
#   'Societe les Tissandiers France',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJR8LaZ9lx5kcRAdbWb4Bf-K8': ((48.8520573, 2.3369246),
#   3.8,
#   'Natalys',
#   ['lodging',
#    'clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJD7i5V_Fu5kcRtxjy4VDR08w': ((48.9020637, 2.3424388),
#   -1,
#   'Gallot Franck',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ0cjlfFlw5kcRCzCbOaBI3J4': ((48.82160260000001, 2.3045179),
#   3,
#   'L EUROPEENNE DE L AMEUBLEMENT',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJi_OGDNxx5kcRxmkSCb0dFjk': ((48.8504154, 2.3389583),
#   -1,
#   'Cappellone Olivier',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJzWNZ0MRt5kcRwgUYRJo94MY': ((48.8827524, 2.3808589),
#   -1,
#   'Codjia Jérôme',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJUenKisdt5kcRp4PSPIGyUAY': ((48.8843322, 2.3916789),
#   1,
#   'LABRADO Concept',
#   ['general_contractor',
#    'plumber',
#    'electrician',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJAQAAR99k5kcRB_gbsjMEi1A': ((48.8743371, 2.2323855),
#   -1,
#   'Shelving and Storage',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ90nF8t5s5kcRUHqonDlXbeQ': ((48.89824240000001, 2.441472),
#   3.4,
#   'Yesmeubles.com',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJRT0dKutt5kcRM-wVt9jh9tE': ((48.8728518, 2.3904598),
#   -1,
#   'Objet Direct',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJfewiAqsS5kcR_PoSMtPcqU4': ((48.85633170000001, 2.4595395),
#   -1,
#   'Longuet Philippe',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJe-O8ppNv5kcRKNxM6d8s30s': ((48.8801666, 2.2939733),
#   4.3,
#   'Mis en Demeure - Bayen',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ8TNMhs8S5kcR-K1NS7uFink': ((48.8818267, 2.4703039),
#   1.2,
#   'HomeSalons',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJxeXNJXlt5kcRS-t_r6luRH8': ((48.8602213, 2.4154439),
#   5,
#   'Ecomeubles Gallieni',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJOyFrhX1t5kcR7_aONPJC-QQ': ((48.855235, 2.4197268),
#   -1,
#   'Worldmobili',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJy5tSxVJu5kcRxJipSjJKZhk': ((48.8886705, 2.325299),
#   -1,
#   'Trancoso Manuel',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQbYfDgZu5kcRumlximhT9pw': ((48.8650495, 2.3627541),
#   -1,
#   'Expert Art japonais & Kōgei',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJFYdXAvpu5kcRnvLOLDZ58OM': ((48.90185389999999, 2.3364692),
#   4.5,
#   'La Trouvaille',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJBcgavZFt5kcRG1aiLAcoiyk': ((48.866901, 2.397497200000001),
#   -1,
#   'débarras brocante',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJeygP1FB65kcRl3sqqjKYRMM': ((48.81266189999999, 2.237431599999999),
#   -1,
#   'Lainé Jean-Christophe',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJZe5LmHNy5kcR-p1tSejrt7o': ((48.8491406, 2.3922143),
#   3,
#   'A La Compagnie Du Placard',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJiUVkrY1l5kcRr6sbszQPm14': ((48.9148541, 2.2732586),
#   -1,
#   "Ambiances D'Intérieur",
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJNUaWTIJv5kcRUZ4lAQs4lCo': ((48.89460080000001, 2.2878749),
#   -1,
#   'Pommart René',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJBedQV8Fx5kcRskVLYu5NMxE': ((48.8409668, 2.3382552),
#   -1,
#   'Bargueños',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ--JM6Spu5kcRc3iM5Y4q7AI': ((48.85817420000001, 2.3239417),
#   -1,
#   'Baudoux',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJV8eK92kN5kcRRBamp3oNVAA': ((48.83834259999999, 2.478703799999999),
#   -1,
#   'Atelier Decoration Richelieu',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJsQcJccUS5kcR81oAESsz8wA': ((48.881789, 2.4714188),
#   1,
#   'Natuzzi',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ-ZOLqiFs5kcRpdP-BWCaRD4': ((48.91358959999999, 2.3747032),
#   -1,
#   'Sdf Meubles De Boutique',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJd1EdghBu5kcRsijs8D3poJc': ((48.8662406, 2.3530974),
#   -1,
#   'Lbs Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJNduikjps5kcR1t2uY2ORWxw': ((48.9070542, 2.3846498),
#   -1,
#   'Deger Spma',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJR0Y95WBl5kcR-aGs-bri-hU': ((48.8794693, 2.2752636),
#   5,
#   'Archea Neuilly-sur-Seine',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJbT4fRNlv5kcRL2LsxT_jFuM': ((48.8609827, 2.3064629),
#   5,
#   'Cousins Sosegh Associés',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJoxIu2zsT5kcRXZTo0JPV_zU': ((48.90798759999999, 2.4763371),
#   -1,
#   'Soc Nouvelle Rebuzzi',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJC_dUd_dt5kcRuwDYsmyU-Og': ((48.8582957, 2.3788713),
#   -1,
#   'Horvath Jean-Claude',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJc3ctsK9l5kcR-QZvDCzEvYY': ((48.906932, 2.245111),
#   4,
#   'GITEM Cuisine - GraniteOnline - UDLM',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ_3PL-EVt5kcRBgJxw8EL4Yg': ((48.86897889999999, 2.4465687),
#   5,
#   'Mercier Tiresias',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJq6o6X7xv5kcRWSl19SH7j0I': ((48.88458300000001, 2.305726),
#   5,
#   'CUISINES DIRECT PARIS/HOME DESIGN 17',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJzXnlsglw5kcRZoAkG_kEx8w': ((48.8448259, 2.27817),
#   4,
#   'Drouault Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ-0u6Bo9x5kcR67kavPnaux0': ((48.8756938, 2.3970738),
#   2.5,
#   'Mobeco',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJq6rWau1x5kcRPUb5CmL4XVU': ((48.8373189, 2.3527488),
#   4.7,
#   'Bureau Vallée',
#   ['electronics_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQcRSLUEN5kcRAvlaw6SubIE': ((48.8364965, 2.4723051),
#   1,
#   'Froment Jacques',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ_bqT-Dpt5kcRpnRTMJFAIRw': ((48.8818344, 2.4455011),
#   -1,
#   'Capitao Manuel',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJsS4n1qd65kcR8xbbZkJzpxg': ((48.8475567, 2.2740246),
#   1.4,
#   "Interior's Paris 16e",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJwy1-Lflt5kcR2pAXLyOL-mY': ((48.8533767, 2.3751638),
#   5,
#   'Cosme Literie',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJA4tuIwRy5kcR3vji6ro2i4s': ((48.8497304, 2.3734147),
#   5,
#   'Nicolas Thibout',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJed4brN5x5kcRO7BLGzITSbI': ((48.851668, 2.338782),
#   5,
#   'Librairie Amélie Sourget',
#   ['book_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJXz9oAxZu5kcR6nNXyBVb7II': ((48.849709, 2.370134999999999),
#   -1,
#   'Absolute Office',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJTwcVQfFu5kcR1Puxk1xHWMw': ((48.9027082, 2.341577),
#   -1,
#   'Goldmann Michael',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJxcHo-Axy5kcRkF6Lzaoqzg4': ((48.8494172, 2.3849864),
#   4.5,
#   'Soubrier Antiques and Decor - furniture rental',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ6wbrKBhw5kcR5mLeh0aEKG0': ((48.8473434, 2.296595399999999),
#   5,
#   'Espace Canapés Lits Diva STORE',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhxbCTSBu5kcRDA8GfOZWYhg': ((48.8591203, 2.3434702),
#   3.5,
#   'Habitat Paris Pont-Neuf',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJFQ07AwZy5kcRZaoeDctdERI': ((48.8511276, 2.377435600000001),
#   -1,
#   'CaraColo',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJawUh9f1s5kcRg3qVBL3u6UU': ((48.89505810000001, 2.4222254),
#   -1,
#   'Bazar Mobilier Deco',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJi8YWG6tv5kcReC7Qchi1VSY': ((48.8940418, 2.3229711),
#   -1,
#   'Instama France',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ04QiZI5v5kcRunAUp_Cie5c': ((48.8832032, 2.2880518),
#   -1,
#   'Menuiserie de Batiment Roux Freres',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ7_K0MFVy5kcRt0fAewr1HSs': ((48.8152493, 2.406705),
#   4.6,
#   'Maximum',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJqeG-iYN65kcRg0AKFxe7Km0': ((48.8242749, 2.2686393),
#   5,
#   'Atelier des Meubles Anciens',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJrypT9RFu5kcR-TAQmQWnIag': ((48.8710966, 2.3555184),
#   -1,
#   'Briemel Jean Ebeniste Jean',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJj0tsGKIS5kcROCoCbqdeE6o': ((48.8589406, 2.4784488),
#   -1,
#   'Plastixia',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJD3fpExpu5kcRSiybsAoxfKQ': ((48.8653168, 2.351654599999999),
#   3.8,
#   'Cinna',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ64BVSNdx5kcReH2Ya8iaqY8': ((48.8518558, 2.3316404),
#   3.6,
#   'BoConcept Paris 6ème - Rue de Rennes',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJH6ZHaalt5kcRbzHOqHflZfE': ((48.8892354, 2.4108359),
#   -1,
#   "L'Ecorce",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJTRwsIotv5kcR3L0U88rB3uM': ((48.8790073, 2.2821327),
#   -1,
#   'Freval',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhXXSslFu5kcR6n01NNw7wic': ((48.8887009, 2.332925099999999),
#   4.2,
#   'Herbert Emmanuel encadreur',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJdV1XivNv5kcRHRcBovQhjys': ((48.874237, 2.2846081),
#   -1,
#   'N1 du meubles - Home Concept Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJT-YvR8Rv5kcRhoPl74S5HDg': ((48.8707489, 2.307915399999999),
#   5,
#   'Office Bureau',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJszgj1CRu5kcRBqUWnypIlYg': ((48.8663543, 2.3367092),
#   -1,
#   'canape cuir Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ4YyESulv5kcR8rAl_5q2W5o': ((48.8710844, 2.2952454),
#   5,
#   'PHS PHILIPPE SIRAUD',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJM1pjInVu5kcRzGExIBcqu5Y': ((48.87715919999999, 2.3663859),
#   -1,
#   'Kroliczek Jean',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJy6xrEihu5kcRxbJASiLbiQI': ((48.8574968, 2.332553),
#   -1,
#   'DADA cuisines',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJv9xyhxdw5kcRd9rJdnC1MxY': ((48.84704900000001, 2.2963977),
#   -1,
#   'Topper Meubles',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJiwWOMBpu5kcRYc2hp5_f0UM': ((48.86420380000001, 2.3516598),
#   -1,
#   'Sajuni Et Compagnie',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJb-VdsoNv5kcRUxiHhFsBO70': ((48.8926871, 2.2900464),
#   3.4,
#   'Casa',
#   ['shopping_mall',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJlcSylTJw5kcRWUH_XiXTYGA': ((48.8455781, 2.319598),
#   -1,
#   'Paringer',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJYeLQ6dFx5kcRHR1VEblevmQ': ((48.8473082, 2.328405),
#   5,
#   'Archea Paris 6ème',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJV_X5kJ1v5kcRk1VwCWDDoDA': ((48.8967198, 2.2952007),
#   -1,
#   'Mauduit Jean-Claude',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJVZMOv1Rl5kcRTruw0YArncQ': ((48.8586933, 2.2729854),
#   -1,
#   'Cera Sa',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJgaCHQ6565kcRHV8IOLyy-IA': ((48.8512178, 2.2672594),
#   -1,
#   'Bergia Le Marois Monique',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJn-qP8bRz5kcR3gAgE5CAjFw': ((48.81314839999999, 2.389722599999999),
#   -1,
#   'Vainglas',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJlyqAIypu5kcRuI24CJQtafc': ((48.858088, 2.3272486),
#   -1,
#   'Moissonnier',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJnX87lgty5kcRy3rDDaREM2w': ((48.8515334, 2.3847069),
#   5,
#   'Rosello Frères',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJn7OMYeJs5kcRDht-ELR3CFE': ((48.8957279, 2.429492999999999),
#   -1,
#   "Cap'projets",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJW2DEatlx5kcRQuVyORFYQ38': ((48.85260239999999, 2.3369271),
#   3.8,
#   'La Joie de Vivre',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJKYeUHgtv5kcRAHYgeQN5y-0': ((48.9000482, 2.3048518),
#   -1,
#   'Atelier Cézario Padouck',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJc1nyVoNt5kcRO02_6rFk9RY': ((48.8648845, 2.4078476),
#   -1,
#   'Ammour Mouloud',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJL6C5P3Ny5kcRzeXDmZef-98': ((48.8488219, 2.3900713),
#   4.5,
#   "L'EDITO",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJnQYiZ6xy5kcRfYLYGpn4_6Y': ((48.8478984, 2.4529124),
#   -1,
#   'L2C',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJvSQRYKV65kcRZp7DHv3KUYY': ((48.8476593, 2.2666206),
#   5,
#   'Relookitchen',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJg_eTExpu5kcRkSoDVE7UpEg': ((48.8654642, 2.3524699),
#   1,
#   'Ory Toons',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJsbkQiM8S5kcR2hNjGWNPr6k': ((48.8820905, 2.4698287),
#   -1,
#   'Calligaris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJfbOy0DJy5kcRCmb5DtXtf2I': ((48.8160663, 2.376952499999999),
#   -1,
#   'SIG Distribution',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJA244uM5t5kcRlAT91EvzJp4': ((48.8894843, 2.3858242),
#   -1,
#   "L'état de sièges",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJwfttrMUS5kcRXj0hmO-A5YU': ((48.8819258, 2.470052899999999),
#   2.1,
#   'Cuisines AvivA Rosny-sous-bois',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJw4ONwWJt5kcRZx_G5l8O5Ac': ((48.856164, 2.424718),
#   -1,
#   'Habitat Ameublement Social',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJZ-xzmEFu5kcRPXETvXN37sw': ((48.880195, 2.3441681),
#   -1,
#   'Rabillé Christophe',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJA5wU3VFk5kcRUKtwy4Yezak': ((48.90780519999999, 2.2303625),
#   2.4,
#   'Dépôt 1 Conforama Colombes',
#   ['storage',
#    'electronics_store',
#    'lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ44zDF8YS5kcROOebbDUbD5Q': ((48.8775681, 2.4708559),
#   -1,
#   'Distri.mob',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJzSijSsRv5kcRJCxWCW6M0NE': ((48.8707505, 2.3090224),
#   -1,
#   'Mooti',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ5_Py-VZt5kcRWFMfbedgfNg': ((48.82560739999999, 2.3326773),
#   -1,
#   "L'odyssee.",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJMfu8ppNv5kcR3asKt9NgDNo': ((48.88083200000001, 2.2931952),
#   -1,
#   'IHT',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ4WdJwHBw5kcRr4uP6_W52EU': ((48.8286753, 2.281759),
#   -1,
#   'Micadho',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJwTZs_VJ85kcRDAbYguWcCUA': ((48.87558360000001, 2.3022004),
#   -1,
#   'iNDEXoFdESiGN',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJD9uGrmZv5kcRewjYR2vDPSs': ((48.91342100000001, 2.2876218),
#   5,
#   'Guegan Et Fils',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJrR41qwRu5kcRiFyJX4bI_8g': ((48.861251, 2.356124),
#   -1,
#   'Perrine Rousseau Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJBaDtc11u5kcR1GHbNjImbdA': ((48.888569, 2.346001),
#   -1,
#   'Bourbon Mobilier Collectivités B.M.C',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJNfyluxNw5kcRM9aL3g7hJNs': ((48.8403607, 2.2903853),
#   -1,
#   'Futon Santé',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ24vyAbZx5kcR5OG94n5HJ3g': ((48.8363711, 2.3263093),
#   5,
#   'Happy Home',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJn9Y-RsQS5kcRPhwU-w9-okg': ((48.88140169999999, 2.471230799999999),
#   1.1,
#   "Château d'Ax",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ7fRuTPFu5kcR-CTdgdN359M': ((48.9041338, 2.338812700000001),
#   -1,
#   'AU TRESORANTIC',
#   ['jewelry_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJo53z30Bw5kcR4QL85kKfH5Q': ((48.8348658, 2.3017764),
#   -1,
#   "Feuille d'Or et Mercure",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ_8DXXvxy5kcR80fbtNYfIcw': ((48.8179635, 2.4169518),
#   -1,
#   'Grandes Cuisines',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJaxFJxlBu5kcRASwqgP6Y0ds': ((48.890916, 2.334338),
#   4,
#   'Chez Will',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJzfkRI49y5kcRnCTPdOWsTkA': ((48.8426406, 2.4175737),
#   -1,
#   'Shoe Case',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJY5yHS9Jx5kcRuthPZ16TFvM': ((48.8489684, 2.3250528),
#   4.4,
#   'Cherche Midi Droguerie - Bricolage - Cuisine. Ancienne Maison Raclin',
#   ['hardware_store',
#    'health',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJUWyzIrRx5kcRnhxqvyCQDbo': ((48.8329268, 2.3250928),
#   2.3,
#   'Bambins Déco',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJF4ck5gNz5kcRliLpZ4lVdxs': ((48.81049549999999, 2.4144107),
#   -1,
#   'Lambert Françoise',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhUE40zts5kcRCAH-JOFwbGI': ((48.908272, 2.387748),
#   5,
#   'Meubeo',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ04Rwpmdy5kcR8vsbjmBSllU': ((48.8366863, 2.401537),
#   -1,
#   'Meubles Bois Exotiques',
#   ['furniture_store',
#    'natural_feature',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJi5dKdg5w5kcRP1waC_Yg61M': ((48.8424878, 2.285231),
#   5,
#   'Archea Paris 15ème',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ2VDZkXVx5kcRBw9NwNhVcNo': ((48.8153063, 2.3448081),
#   -1,
#   'Armelle P Créations',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJkR4JHUtu5kcRnMumEf7vBkA': ((48.87932099999999, 2.3258283),
#   -1,
#   'Design & Conseil',
#   ['furniture_store',
#    'general_contractor',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ890bQo5v5kcRDia9mrG3FPc': ((48.8840152, 2.2892463),
#   -1,
#   'Surfaces et Cuisines',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJF0jVhMdt5kcRjbljktHE3do': ((48.8834357, 2.3910338),
#   -1,
#   'Broquantic',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJM2m3OzFw5kcRBPAg-LFLReA': ((48.842532, 2.3133454),
#   -1,
#   'Décoration tapisserie Henriette Trejtnar',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ73ZcCdVy5kcRsu9zgWlUiKs': ((48.8153375, 2.4507554),
#   -1,
#   'Atelier Robert Leyx',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJS_BX1gdu5kcRBsan5Kp-AgY': ((48.8657841, 2.3655813),
#   3,
#   'MOB CUISINES',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJrT6pZ6Vl5kcRKJ8wUbk9w4A': ((48.907136, 2.248054),
#   5,
#   'Domeau Pérès',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJUW-REfJt5kcRL3yxzDVCdQ0': ((48.8647936, 2.3857432),
#   -1,
#   'Groupe Paris Meuble',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJExedMLNv5kcRU6Otdh-Txaw': ((48.8834683, 2.3230932),
#   -1,
#   'Métisse',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJNxLty6J65kcRJzINSsZBO0M': ((48.8392628, 2.2652968),
#   -1,
#   'Evrard Jeanne',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJR5pLcGNw5kcRaKOYXRSDMRs': ((48.8212589, 2.287617),
#   -1,
#   'OSM France',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJk07sE4Vv5kcRyTBwOHMbZ6g': ((48.8890717, 2.2890026),
#   5,
#   'Patrick Pierre Ebénisterie',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJUc8PJTtz5kcRcsDXCsJEFlk': ((48.8774451, 2.435592),
#   4.5,
#   'EASY CUISINE',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ86EOa0Vu5kcRvlRQLtziehM': ((48.87063, 2.346829),
#   -1,
#   "L'Atelier MARINKA",
#   ['real_estate_agency',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJqx0qhh1w5kcRfzGtOn-D7tU': ((48.8571044, 2.2918654),
#   -1,
#   'V2',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJvzhsYphx5kcRUliF7DXtBVw': ((48.8234325, 2.342773499999999),
#   -1,
#   'Billard Stephan Matthew',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ8TaTQ0tu5kcRSWPDRguy3xQ': ((48.8809347, 2.3250902),
#   -1,
#   'CAD Couture',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJiV_Ao2xw5kcRs290usgpIv0': ((48.8361198, 2.2916682),
#   5,
#   'Elles Décorent',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJif1JKpNv5kcRlgpxjl45Zh0': ((48.8775562, 2.2929025),
#   1,
#   'Antiquités la Marotte',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJWVkrrkds5kcR4ksWlqL6-6k': ((48.9071933, 2.3955911),
#   3,
#   'Futur Meuble 2015',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJCfeAQLdx5kcRuisb1N60G1k': ((48.8321419, 2.3302858),
#   -1,
#   'Atelier Bis',
#   ['general_contractor',
#    'lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJP_4BEaxv5kcRZeCG3BFFdpM': ((48.8911611, 2.3202051),
#   -1,
#   'Zinck Alain',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJpfUELZBu5kcRMbWgq_WwzhE': ((48.9070686, 2.3578582),
#   -1,
#   'Soc Sauvel',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJVYsCqw5y5kcRhvJCqka3KoE': ((48.85057459999999, 2.3839313),
#   4.3,
#   'Citeaux Mural',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJDZPep4lt5kcR_c5zNpIJNhw': ((48.8575679, 2.3972748),
#   -1,
#   'Boat Safran.creation Sophie Lescot',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJpbQGhW5l5kcRdkmkYJ5ZNwc': ((48.8851473, 2.2630829),
#   5,
#   'Durififi',
#   ['clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJBybmmA9v5kcRtSpHwOVcnlg': ((48.9050597, 2.3131036),
#   -1,
#   'C.c.b',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJKZeNzTtu5kcRJ8CH_0WSnVQ': ((48.870485, 2.337686),
#   -1,
#   'Fil et Matière',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJKYHem3Zu5kcRy-e8pjCptMg': ((48.8810941, 2.3654594),
#   -1,
#   'Ligne et Couleur',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ6aicbNZx5kcRkbID0ip3oKw': ((48.85522220000001, 2.3285074),
#   -1,
#   'Société D et P',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJU7uMIepx5kcRe86M6c3-9Hg': ((48.8410227, 2.344629),
#   5,
#   'Thyrse Paris - tapissier décorateur',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ3dmfheFt5kcRUzzbdQDQqQQ': ((48.8712737, 2.3703904),
#   -1,
#   "La Companie Limitee'des Confort Meubles",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJtXm9AgJu5kcR9r0bLjfxtyU': ((48.85996850000001, 2.3609881),
#   -1,
#   'Cuisines Milet',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJV46OHZRv5kcR8lj4A5EoHkI': ((48.8811517, 2.288734),
#   -1,
#   'Roche Jean-Paul :atelier de la methode ancienne',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJWc7M79Rx5kcRubY46-9GuJk': ((48.85346219999999, 2.3238394),
#   -1,
#   'La Paresse en Douce',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ74Vi6WJw5kcR2tFFxUrdtBs': ((48.8186529, 2.2867943),
#   -1,
#   'Lajnef Najah',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJxQwb62Vy5kcRdY5oGE38xvY': ((48.84073899999999, 2.4006369),
#   -1,
#   'Société Gérard Conte',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhRQx0slt5kcRF1CMuiJCnxI': ((48.8881899, 2.3914667),
#   4.7,
#   'Bellynck and Son',
#   ['real_estate_agency',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJn9AJVKNv5kcRL-A78H6v_6U': ((48.8873038, 2.3074398),
#   -1,
#   'Matériel Pro CHR',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ5-kt7m5y5kcRQ6MK7b9flHM': ((48.84197089999999, 2.3956998),
#   -1,
#   'Galatry Stephane',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQ39PhNVx5kcRRu9ge8o89ZE': ((48.85512900000001, 2.327452),
#   5,
#   'Roche Bobois',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJm-VlWatv5kcREzxn0p-WM1A': ((48.8921247, 2.3239835),
#   -1,
#   'Mobex France Sarl',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ-_Q4AuRx5kcRjPAtt3bL1RM': ((48.8506861, 2.3497655),
#   5,
#   'Vergain Philippe',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ-0u6Bo9x5kcR2RxgFWV0Qos': ((48.8763956, 2.2837828),
#   2.9,
#   'Mobeco',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhwg5uuxv5kcRIo_r1HUUQ-0': ((48.8762401, 2.2949294),
#   4,
#   'SCANDISHOP (antiquités Rafael)',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJwTYkCUVw5kcRJsGFmmcbOw4': ((48.8291768, 2.3068599),
#   -1,
#   'Hier et Demain',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ0UR1yipu5kcRLYy71GRMu3c': ((48.857933, 2.322382),
#   5,
#   'Mondomio',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
# ...
#   -1),
#  'ChIJs5dDQwVl5kcRhCx5Ke-AOpI': ((48.88940700000001, 2.245255),
#   -1,
#   'Stylinside',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJh2Rf841v5kcRYjFuChwyjnE': ((48.881303, 2.28996),
#   -1,
#   "Tapis d'Orient et objets d'art de Chine et Japon",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJNY6veDJy5kcR1f_E05beSgE': ((48.81815750000001, 2.374864800000001),
#   -1,
#   'Gautier',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ28hua7Fl5kcRReCxv3ezjEQ': ((48.912054, 2.243854),
#   4,
#   'Espace Aubade Batimantes Colombes',
#   ['car_repair',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJO-R6KNpt5kcR37XlPJ9FiXA': ((48.8838436, 2.3750066),
#   -1,
#   'Bloucard Alain',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJR1wTG7Rl5kcR_tGAm1MQGsE': ((48.91440300000001, 2.2419133),
#   -1,
#   'Taillepied de Bondy de Moulins Diane',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ0aZUrR5l5kcRpsr2ETWamfY': ((48.882817, 2.2398844),
#   1.5,
#   'La Compagnie du Lit',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJubQwAx9w5kcRrbWK-kg3bd0': ((48.8540173, 2.2967728),
#   -1,
#   'Lolalix',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ1arXg3hl5kcRMqJLR5b7Odg': ((48.89796250000001, 2.2724252),
#   -1,
#   'Vallée Alain',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJiy30dq1z5kcRg51lRnckntc': ((48.8125046, 2.3979819),
#   -1,
#   'S Et L 168',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhQ5SMJZy5kcRSjsdOlmLGuk': ((48.84150719999999, 2.432270899999999),
#   -1,
#   'Home Global Store',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJc646vxlu5kcRxP6cCPNRdxI': ((48.86484329999999, 2.3490739),
#   -1,
#   'Pm Co Style',
#   ['painter',
#    'general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJId-sFBpu5kcRJUIr1372fUA': ((48.865165, 2.352221),
#   5,
#   'Le Lit - Paris 3 Sébastopol',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQU5lDtVs5kcRvNl8-mZzVDg': ((48.8957936, 2.4580129),
#   4,
#   'S.E.A Société Ebénisterie Agencement',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJLbaZqDwT5kcRE48b0UClTco': ((48.90437379999999, 2.4782166),
#   -1,
#   'Grahovac Milos',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJAfMFEA1t5kcRWskMG8kBSSE': ((48.87660150000001, 2.422864),
#   3.8,
#   'ALLO CHR',
#   ['bakery',
#    'bar',
#    'restaurant',
#    'food',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJf8ZfiNVx5kcR7ZTXJyQ85ww': ((48.85658659999999, 2.3256332),
#   -1,
#   'Frau France',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJI4-mVud65kcRZxWPYdG9XCE': ((48.82851279999999, 2.2450207),
#   5,
#   'P-pose PLACARD',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJvQUMUwNu5kcRbvN2cbNI8Bc': ((48.8606106, 2.3562164),
#   -1,
#   'Agencement Tertiaire',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJn9Y-RsQS5kcRzeVE0CTKUYQ': ((48.8821466, 2.4705283),
#   3,
#   'Espace Loggia',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJOWy1dutv5kcRPWldeeBP-us': ((48.8751223, 2.2964015),
#   5,
#   "L'appartement Ticolas",
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJWdoTkHxy5kcR5pYQbX9ePQs': ((48.8466554, 2.4063461),
#   -1,
#   'JMSTONE France',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJGaPYEQRu5kcRZ_ZjiHMTtP0': ((48.8615589, 2.3608265),
#   5,
#   'NORDIK Market',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJO3BEheZx5kcRuqL6nBS05jc': ((48.849195, 2.34886),
#   5,
#   'OmKashi La Lucarne',
#   ['art_gallery',
#    'jewelry_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJN7zNkmpu5kcR1u4gchxmFYM': ((48.87809289999999, 2.3476504),
#   -1,
#   'Ribeiro Manuel',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJTXf7OJ5l5kcRlK4BQWxdEQI': ((48.89924799999999, 2.2616627),
#   -1,
#   'NOBLESSA CUISINES',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJX9xDNJ5l5kcRXyDg2LnN-KE': ((48.8991789, 2.2611744),
#   -1,
#   'Societe Auxiliaire de Menuiserie',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJlUXkx_9t5kcRnJwOnnakkU8': ((48.8576042, 2.3684879),
#   -1,
#   'SPT',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJexWxDi5u5kcRN1FwbywhMc0': ((48.86576830000001, 2.3287129),
#   -1,
#   'Bis Conseil',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJo3NBdnpy5kcRsVK3p6VIp4w': ((48.84842880000001, 2.4001154),
#   3.4,
#   'CASTORAMA Nation',
#   ['home_goods_store',
#    'furniture_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJYUIQ1qhz5kcRpS_MPZvedPE': ((48.8071555, 2.402457800000001),
#   -1,
#   'Au Bonheur du Confort',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJQTGXD9Jx5kcRe3cHNIcEB7U': ((48.8454782, 2.3238681),
#   5,
#   'Club Objet',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJCz2l49Vx5kcRjCL8kEyN_Gw': ((48.8557506, 2.3273346),
#   -1,
#   'JB Creations',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJuZcVseJx5kcRxB5nzIvmais': ((48.8548823, 2.3556193),
#   -1,
#   'Lambert Lambert',
#   ['art_gallery',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJTS6zUAZu5kcRxAQ9wr_Ge6I': ((48.86373, 2.364188),
#   5,
#   'beunperfect',
#   ['clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJmaGtffRx5kcR2GzazXuMQNk': ((48.838431, 2.36033),
#   5,
#   'Marchand de curiosites theme',
#   ['home_goods_store',
#    'furniture_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJWU79dmxy5kcR6slt4_FHocQ': ((48.8403249, 2.391814499999999),
#   -1,
#   'Ged Cucine',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ2ajLp7tv5kcROJFQ7dIlOKI': ((48.88448030000001, 2.309463),
#   -1,
#   'Ets claus',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ8bEw3vdw5kcRM802slPbiIc': ((48.81654820000001, 2.3061062),
#   5,
#   'Dereta',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJR8f4I5xl5kcR0JsLTSxNnsI': ((48.9014354, 2.2642308),
#   3,
#   'Cuisine1',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ08uxDHhu5kcRCcCoHmwqRqQ': ((48.887072, 2.369476),
#   -1,
#   'déco meuble',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJVbtJvJi85kcR7uuhNuirTJs': ((48.846689, 2.310031),
#   5,
#   'PINET DÉCORATION CRÉATION RESTAURATION',
#   ['clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJTf6m5nNy5kcRuLP9beylj3I': ((48.8492523, 2.3939745),
#   5,
#   'Pierres à la Mesure',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJddsPh0Ru5kcRNYe5TM8KJyc': ((48.884184, 2.340498),
#   3.9,
#   'Petit Pan',
#   ['clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJmQnlkYlt5kcR1LqZR7J2mfI': ((48.8568108, 2.395881799999999),
#   -1,
#   "Yvane Moissenet Tapisserie et Décoration d'Ameublement",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJV3IDYlVl5kcR1MTlBtovK9Y': ((48.8587855, 2.2764916),
#   4,
#   'SieMatic Paris 16ème - Notre-Dame Décoration',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJefdtsjhw5kcRAbjl3hlOyPs': ((48.8375771, 2.3038625),
#   -1,
#   'Majerna Lits rembourrés deux places et une place',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ1RVqqV165kcRkexmtBohXok': ((48.81055500000001, 2.248614),
#   5,
#   'Le cozy corner',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJBVd3bRpu5kcRBitHlhPjWNs': ((48.865465, 2.352406),
#   5,
#   'Vestibule paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJv9ULmq9t5kcRmaMVeKuVfoo': ((48.8860631, 2.4052401),
#   -1,
#   'Le Lit National F Pejaudier',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJcRtGrhNw5kcRnu2Y4c6zsa4': ((48.84022799999999, 2.290285399999999),
#   -1,
#   'VARIATION',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJJ4Qx5hhu5kcR6X1YLDuuKDg': ((48.8661823, 2.2815812),
#   -1,
#   'Open en Ville',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ48egrHFw5kcRWZ-rmym3ER4': ((48.82907519999999, 2.2829412),
#   1.7,
#   'Mobalpa Issy Les Moulineaux',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJU4LmFVtt5kcRxmISiCWJJRU': ((48.8629137, 2.4422387),
#   -1,
#   'Société M.D.M.',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJYe24ZgZy5kcRavdigfH1ZtM': ((48.8517151, 2.3756397),
#   -1,
#   'TASSIN Cuirs SA',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJheSg1GRy5kcRyU50MKVBMeo': ((48.8451189, 2.4036448),
#   -1,
#   'Sembois',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJN6AvzUFw5kcRKfH0xt5bF2k': ((48.83444179999999, 2.2983886),
#   -1,
#   'Echo Agencement Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJTcBgdSoN5kcRzU7aho_PUF0': ((48.813596, 2.4575005),
#   4.1,
#   'Futon Factory',
#   ['lodging',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ74GC5TJu5kcR79jA5PN51I8': ((48.8686004, 2.3248179),
#   3,
#   'Le Studio des Collections',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ--2lmgly5kcR9pVh76x4Q_0': ((48.8534987, 2.3829069),
#   4,
#   'Decobois Plus',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJi1VVLAhu5kcR47QyM2OgtZs': ((48.8680918, 2.3673629),
#   4.4,
#   'Steelcase SA',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJJZpWG3By5kcR29kMT9LFzco': ((48.84536600000001, 2.399049),
#   3.5,
#   'ESTIM NATION',
#   ['car_dealer',
#    'finance',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJhxubxcgS5kcRV6WlfijKncg': ((48.8781456, 2.468315599999999),
#   -1,
#   'M L Eurl',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJM-1PEAlu5kcR5lgFudnjwK0': ((48.8692241, 2.3643296),
#   -1,
#   'Jean Chatel Diffusion',
#   ['clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ4VEjCXl65kcRxjOMum8Rzzg': ((48.8069965, 2.2677408),
#   -1,
#   'PERENE Clamart',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJB358CeRt5kcRExf275aA7ss': ((48.8698044, 2.3739129),
#   5,
#   'Diva Store',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJV6C5P3Ny5kcRVTQzIzVeqks': ((48.8539539, 2.3572164),
#   5,
#   "L'Edito",
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ21mdRwJv5kcRFxQLmFaxu1U': ((48.9032711, 2.323901299999999),
#   -1,
#   '2eme Chance',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJec8qbCJw5kcRPAnzeXfcQeA': ((48.850663, 2.2991769),
#   -1,
#   "L'Autre Maison - Fabrice DIOMARD",
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ7XUYF9hx5kcRootSkBWQQeY': ((48.85541509999999, 2.333995499999999),
#   -1,
#   'Simrane',
#   ['lodging',
#    'clothing_store',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJX1ErDdRx5kcRveZUZB91r7A': ((48.851776, 2.318148),
#   -1,
#   'Hamilton Conte Paris',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJ_-rtJQFy5kcRHQCC2B80tsM': ((48.8527784, 2.3715285),
#   3.6,
#   'Roset Hotels et Contracts',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJh5jWZ_1v5kcRTyjdSvy4d6U': ((48.8578459, 2.2870277),
#   -1,
#   'Sessler Claude',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJT67regRy5kcR0KogR5SvdXQ': ((48.84870350000001, 2.3720455),
#   5,
#   'SieMatic Paris - Notre-Dame Décoration 12ème',
#   ['general_contractor',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJw24f6kZw5kcRaxamB_q9fhY': ((48.8334029, 2.3047617),
#   -1,
#   'Maonia',
#   ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJuaLQgLVx5kcRB1peYcZjWco': ((48.83637299999999, 2.3237138),
#   5,
#   'Archea Paris 14ème',
#   ['furniture_store',
#    'lodging',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  'ChIJATdCeTVu5kcRckkK1yPksTQ': ((48.876163, 2.325679),
#   3.1,
#   'Bialetti',
#   ['electronics_store',
#    'food',
#    'furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1),
#  ...}

# %%
def getCoord(poidata, typepoi):

    ## Creation de la matrice des coordonnees des POI
    geo_mat = np.zeros((len(poidata[typepoi]),2))
    for i,(k,v) in enumerate(poidata[typepoi].items()):
        geo_mat[i,:]=v[0]
        
    return geo_mat

def getMark(poidata, typepoi):
    
    ## Creation de la matrice des notes des POI
    notes_mat = np.zeros(len(poidata[typepoi]))
    for i,(k,v) in enumerate(poidata[typepoi].items()):
        notes_mat[i]=v[1]
        
    return notes_mat

geomat_bar = getCoord(poidata, "bar")
notesmat_bar = getMark(poidata, "bar")

plt.plot(notesmat_bar)

# %%
a = np.array([[10,20], [20,60], [30,40]])
b = np.array([1,2,3])
plt.plot(a,b)
# Out:
# [<matplotlib.lines.Line2D at 0x23778ee3668>,
#  <matplotlib.lines.Line2D at 0x23778ee3828>]
